# %%
'''Trains a simple deep NN on the MNIST dataset.
Gets to 98.40% test accuracy after 20 epochs
(there is *a lot* of margin for parameter tuning).
2 seconds per epoch on a K520 GPU.
'''
import keras
from keras.datasets import mnist
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Dropout
from keras.optimizers import RMSprop
from random import randint

# %%
batch_size = 128
num_classes = 10
epochs = 50
activations = ['sigmoid', 'tanh', 'relu', 'linear', 'elu', 'selu']
activations_sigmoid = ['sigmoid', 'tanh']
activations_linear = ['relu', 'linear', 'elu', 'selu']
units = 64
experiments = 10
# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# 60000 train samples
# 10000 test samples

# %%
print('-'*30)
print('Randomized all activations', i)

for i in range(experiments):
    inputs = Input(shape=(784,))
    layers_1 = []
    for i in range(units):
        activation = activations[randint(0, len(activations)-1)]
        layers_1.append(Dense(1, activation=activation)(inputs))

    x = keras.layers.concatenate(layers_1)    

    x = Dropout(0.2)(x)
    layers_2 = []
    for i in range(units):
        activation = activations[randint(0, len(activations)-1)]
        layers_2.append(Dense(1, activation=activation)(x))
    x = keras.layers.concatenate(layers_2)    
    x = Dropout(0.2)(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=inputs, outputs=predictions)

    model.compile(loss='categorical_crossentropy',
                  optimizer=RMSprop(),
                  metrics=['accuracy'])
    
    print('-'*30)
    print('Experiment', i)
    
    history = model.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=2,
                        validation_data=(x_test, y_test))
    score = model.evaluate(x_test, y_test, verbose=0)
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])

# %%
print('-'*30)
print('Randomized linear activations', i)

for i in range(experiments):
    inputs = Input(shape=(784,))
    layers_1 = []
    for i in range(units):
        activation = activations_linear[randint(0, len(activations_linear)-1)]
        layers_1.append(Dense(1, activation=activation)(inputs))

    x = keras.layers.concatenate(layers_1)    

    x = Dropout(0.2)(x)
    layers_2 = []
    for i in range(units):
        activation = activations_linear[randint(0, len(activations_linear)-1)]
        layers_2.append(Dense(1, activation=activation)(x))
    x = keras.layers.concatenate(layers_2)    
    x = Dropout(0.2)(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=inputs, outputs=predictions)

    model.compile(loss='categorical_crossentropy',
                  optimizer=RMSprop(),
                  metrics=['accuracy'])
    
    print('-'*30)
    print('Experiment', i)
    
    history = model.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=2,
                        validation_data=(x_test, y_test))
    score = model.evaluate(x_test, y_test, verbose=0)
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 784)          0
# __________________________________________________________________________________________________
# dense_1291 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1292 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1293 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1294 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1295 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1296 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1297 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1298 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1299 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1300 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1301 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1302 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1303 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1304 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1305 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1306 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1307 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1308 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1309 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1310 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1311 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1312 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1313 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1314 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1315 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1316 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1317 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1318 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1319 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1320 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1321 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1322 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1323 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1324 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1325 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1326 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1327 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1328 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1329 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1330 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1331 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1332 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1333 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1334 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1335 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1336 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1337 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1338 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1339 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1340 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1341 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1342 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1343 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1344 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1345 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1346 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1347 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1348 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1349 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1350 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1351 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1352 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1353 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# dense_1354 (Dense)              (None, 1)            785         input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64)           0           dense_1291[0][0]
#                                                                  dense_1292[0][0]
#                                                                  dense_1293[0][0]
#                                                                  dense_1294[0][0]
#                                                                  dense_1295[0][0]
#                                                                  dense_1296[0][0]
#                                                                  dense_1297[0][0]
#                                                                  dense_1298[0][0]
#                                                                  dense_1299[0][0]
#                                                                  dense_1300[0][0]
#                                                                  dense_1301[0][0]
#                                                                  dense_1302[0][0]
#                                                                  dense_1303[0][0]
#                                                                  dense_1304[0][0]
#                                                                  dense_1305[0][0]
#                                                                  dense_1306[0][0]
#                                                                  dense_1307[0][0]
#                                                                  dense_1308[0][0]
#                                                                  dense_1309[0][0]
#                                                                  dense_1310[0][0]
#                                                                  dense_1311[0][0]
#                                                                  dense_1312[0][0]
#                                                                  dense_1313[0][0]
#                                                                  dense_1314[0][0]
#                                                                  dense_1315[0][0]
#                                                                  dense_1316[0][0]
#                                                                  dense_1317[0][0]
#                                                                  dense_1318[0][0]
#                                                                  dense_1319[0][0]
#                                                                  dense_1320[0][0]
#                                                                  dense_1321[0][0]
#                                                                  dense_1322[0][0]
#                                                                  dense_1323[0][0]
#                                                                  dense_1324[0][0]
#                                                                  dense_1325[0][0]
#                                                                  dense_1326[0][0]
#                                                                  dense_1327[0][0]
#                                                                  dense_1328[0][0]
#                                                                  dense_1329[0][0]
#                                                                  dense_1330[0][0]
#                                                                  dense_1331[0][0]
#                                                                  dense_1332[0][0]
#                                                                  dense_1333[0][0]
#                                                                  dense_1334[0][0]
#                                                                  dense_1335[0][0]
#                                                                  dense_1336[0][0]
#                                                                  dense_1337[0][0]
#                                                                  dense_1338[0][0]
#                                                                  dense_1339[0][0]
#                                                                  dense_1340[0][0]
#                                                                  dense_1341[0][0]
#                                                                  dense_1342[0][0]
#                                                                  dense_1343[0][0]
#                                                                  dense_1344[0][0]
#                                                                  dense_1345[0][0]
#                                                                  dense_1346[0][0]
#                                                                  dense_1347[0][0]
#                                                                  dense_1348[0][0]
#                                                                  dense_1349[0][0]
#                                                                  dense_1350[0][0]
#                                                                  dense_1351[0][0]
#                                                                  dense_1352[0][0]
#                                                                  dense_1353[0][0]
#                                                                  dense_1354[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64)           0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# dense_1355 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1356 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1357 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1358 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1359 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1360 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1361 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1362 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1363 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1364 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1365 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1366 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1367 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1368 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1369 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1370 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1371 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1372 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1373 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1374 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1375 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1376 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1377 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1378 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1379 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1380 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1381 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1382 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1383 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1384 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1385 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1386 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1387 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1388 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1389 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1390 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1391 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1392 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1393 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1394 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1395 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1396 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1397 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1398 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1399 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1400 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1401 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1402 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1403 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1404 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1405 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1406 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1407 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1408 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1409 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1410 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1411 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1412 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1413 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1414 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1415 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1416 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1417 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_1418 (Dense)              (None, 1)            65          dropout_7[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 64)           0           dense_1355[0][0]
#                                                                  dense_1356[0][0]
#                                                                  dense_1357[0][0]
#                                                                  dense_1358[0][0]
#                                                                  dense_1359[0][0]
#                                                                  dense_1360[0][0]
#                                                                  dense_1361[0][0]
#                                                                  dense_1362[0][0]
#                                                                  dense_1363[0][0]
#                                                                  dense_1364[0][0]
#                                                                  dense_1365[0][0]
#                                                                  dense_1366[0][0]
#                                                                  dense_1367[0][0]
#                                                                  dense_1368[0][0]
#                                                                  dense_1369[0][0]
#                                                                  dense_1370[0][0]
#                                                                  dense_1371[0][0]
#                                                                  dense_1372[0][0]
#                                                                  dense_1373[0][0]
#                                                                  dense_1374[0][0]
#                                                                  dense_1375[0][0]
#                                                                  dense_1376[0][0]
#                                                                  dense_1377[0][0]
#                                                                  dense_1378[0][0]
#                                                                  dense_1379[0][0]
#                                                                  dense_1380[0][0]
#                                                                  dense_1381[0][0]
#                                                                  dense_1382[0][0]
#                                                                  dense_1383[0][0]
#                                                                  dense_1384[0][0]
#                                                                  dense_1385[0][0]
#                                                                  dense_1386[0][0]
#                                                                  dense_1387[0][0]
#                                                                  dense_1388[0][0]
#                                                                  dense_1389[0][0]
#                                                                  dense_1390[0][0]
#                                                                  dense_1391[0][0]
#                                                                  dense_1392[0][0]
#                                                                  dense_1393[0][0]
#                                                                  dense_1394[0][0]
#                                                                  dense_1395[0][0]
#                                                                  dense_1396[0][0]
#                                                                  dense_1397[0][0]
#                                                                  dense_1398[0][0]
#                                                                  dense_1399[0][0]
#                                                                  dense_1400[0][0]
#                                                                  dense_1401[0][0]
#                                                                  dense_1402[0][0]
#                                                                  dense_1403[0][0]
#                                                                  dense_1404[0][0]
#                                                                  dense_1405[0][0]
#                                                                  dense_1406[0][0]
#                                                                  dense_1407[0][0]
#                                                                  dense_1408[0][0]
#                                                                  dense_1409[0][0]
#                                                                  dense_1410[0][0]
#                                                                  dense_1411[0][0]
#                                                                  dense_1412[0][0]
#                                                                  dense_1413[0][0]
#                                                                  dense_1414[0][0]
#                                                                  dense_1415[0][0]
#                                                                  dense_1416[0][0]
#                                                                  dense_1417[0][0]
#                                                                  dense_1418[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64)           0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense_1419 (Dense)              (None, 10)           650         dropout_8[0][0]
# ==================================================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
print('-'*30)
print('Randomized sigmoid activations', i)

for i in range(experiments):
    inputs = Input(shape=(784,))
    layers_1 = []
    for i in range(units):
        activation = activations_sigmoid[randint(0, len(activations_sigmoid)-1)]
        layers_1.append(Dense(1, activation=activation)(inputs))

    x = keras.layers.concatenate(layers_1)    

    x = Dropout(0.2)(x)
    layers_2 = []
    for i in range(units):
        activation = activations_sigmoid[randint(0, len(activations_sigmoid)-1)]
        layers_2.append(Dense(1, activation=activation)(x))
    x = keras.layers.concatenate(layers_2)    
    x = Dropout(0.2)(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=inputs, outputs=predictions)

    model.compile(loss='categorical_crossentropy',
                  optimizer=RMSprop(),
                  metrics=['accuracy'])
    
    print('-'*30)
    print('Experiment', i)
    
    history = model.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=2,
                        validation_data=(x_test, y_test))
    score = model.evaluate(x_test, y_test, verbose=0)
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
#  - 17s - loss: 0.4431 - acc: 0.8685 - val_loss: 0.2296 - val_acc: 0.9307
# Epoch 2/20
#  - 6s - loss: 0.2675 - acc: 0.9202 - val_loss: 0.1811 - val_acc: 0.9444
# Epoch 3/20
#  - 6s - loss: 0.2239 - acc: 0.9324 - val_loss: 0.1619 - val_acc: 0.9526
# Epoch 4/20
#  - 7s - loss: 0.2003 - acc: 0.9408 - val_loss: 0.1359 - val_acc: 0.9593
# Epoch 5/20
#  - 6s - loss: 0.1846 - acc: 0.9456 - val_loss: 0.1277 - val_acc: 0.9626
# Epoch 6/20
#  - 6s - loss: 0.1674 - acc: 0.9493 - val_loss: 0.1191 - val_acc: 0.9617
# Epoch 7/20
#  - 6s - loss: 0.1589 - acc: 0.9521 - val_loss: 0.1112 - val_acc: 0.9658
# Epoch 8/20
#  - 6s - loss: 0.1458 - acc: 0.9562 - val_loss: 0.1090 - val_acc: 0.9649
# Epoch 9/20
#  - 7s - loss: 0.1430 - acc: 0.9563 - val_loss: 0.1053 - val_acc: 0.9676
# Epoch 10/20
#  - 6s - loss: 0.1347 - acc: 0.9588 - val_loss: 0.1062 - val_acc: 0.9682
# Epoch 11/20
#  - 6s - loss: 0.1323 - acc: 0.9601 - val_loss: 0.0978 - val_acc: 0.9694
# Epoch 12/20
#  - 6s - loss: 0.1263 - acc: 0.9618 - val_loss: 0.1028 - val_acc: 0.9684
# Epoch 13/20
#  - 6s - loss: 0.1240 - acc: 0.9623 - val_loss: 0.0968 - val_acc: 0.9707
# Epoch 14/20
#  - 6s - loss: 0.1181 - acc: 0.9648 - val_loss: 0.0962 - val_acc: 0.9706
# Epoch 15/20
#  - 6s - loss: 0.1181 - acc: 0.9638 - val_loss: 0.0868 - val_acc: 0.9745
# Epoch 16/20
#  - 7s - loss: 0.1134 - acc: 0.9649 - val_loss: 0.0909 - val_acc: 0.9741
# Epoch 17/20
#  - 6s - loss: 0.1113 - acc: 0.9664 - val_loss: 0.0938 - val_acc: 0.9721
# Epoch 18/20
#  - 6s - loss: 0.1067 - acc: 0.9676 - val_loss: 0.0864 - val_acc: 0.9733
# Epoch 19/20
#  - 6s - loss: 0.1042 - acc: 0.9681 - val_loss: 0.0893 - val_acc: 0.9727
# Epoch 20/20
#  - 6s - loss: 0.1032 - acc: 0.9688 - val_loss: 0.0887 - val_acc: 0.9733
# Test loss: 0.0887332456296
# Test accuracy: 0.9733
