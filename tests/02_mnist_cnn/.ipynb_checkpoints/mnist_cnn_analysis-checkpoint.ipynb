# %%
import pandas as pd
import numpy as np

# %%
experiments = 2
epochs = 40

activations = ['sigmoid', 'tanh', 'relu', 'linear', 'elu', 'selu', 'softplus', 'softsign', 'hard_sigmoid', 'LeakyReLU', 'ThresholdedReLU']
# activations = ['elu']
optimizers = ['rmsp', 'adam', 'sgd', 'Adagrad', 'Adadelta', 'Adamax', 'Nadam']
# optimizers = ['rmsp', 'adam', 'sgd', 'Adagrad', 'Adadelta', 'Adamax']
# colors = ['b', 'g', 'k', 'y', 'm', 'r', 'c']
colors = ['#000000', '#330000', '#660000', '#990000', '#CC0000', '#FF0000',
          '#003300', '#006600', '#009900', '#00CC00', '#00FF00',
          '#000033', '#000066', '#000099', '#0000CC', '#0000FF',
          '#033000', '#066000', '#099000', '#0CC000', '#0FF000',
          '#000330', '#000660', '#000990', '#000CC0', '#000FF0']
lines = ['-', '--', ':', '-.']
cols_f = []
for c in colors:
    for l in lines:
        cols_f.append(c+l)
        

columns=['epoch', 'acc', 'loss', 'val_acc', 'val_loss']
data = []

i = 0
for act in activations:
    for opt in optimizers:
        item_data = []
        
        data.append({
            'name': '',
            'disp_name': act + '_' + opt,
            'col': colors[i % len(colors)],
            'line': lines[i % len(lines)],
            'act': act,
            'opt':opt,
#             'data' : [pd.read_csv('./logs/done/mnist_cnn_' + act +'_' + opt + '_' + str(epochs) + '_' + str(ex)  + '_fd_64.csv', sep=';') for ex in range(experiments)],
            'data' : [pd.read_csv('./logs/done/mnist_cnn_' + act +'_' + opt + '_' + str(epochs) + '_' + str(ex)  + '_64.csv', sep=';') for ex in range(experiments)],
            'averaged': pd.DataFrame(columns=['epoch', 'acc', 'loss', 'val_acc', 'val_loss']),
            'best': {
                'max_acc':0,
                'max_acc_epoch':0,
                'min_loss':0,
                'min_loss_epoch':0,
                'max_val_acc':0,
                'max_val_acc_epoch':0,
                'min_val_loss':0,
                'min_val_loss_epoch':0
            }
        })
        i+=1

max_epoch = 0

# %%
check = pd.DataFrame(columns=['config', 'exp', 'acc', 'loss', 'val_acc', 'val_loss', 'opt', 'act'])
i=0
for d in range(len(data)):
    for experiment in range(experiments):
        check.loc[i] = [data[d]['disp_name'], 
                          experiment,
                          data[d]['data'][experiment]['acc'].tolist()[-1], 
                          data[d]['data'][experiment]['loss'].tolist()[-1], 
                          data[d]['data'][experiment]['val_acc'].tolist()[-1], 
                          data[d]['data'][experiment]['val_loss'].tolist()[-1], 
                          data[d]['opt'], 
                          data[d]['act']]
        i+=1

# %%
check = check.sort_values(by=['val_acc'])
check
# Out:
#                        config exp       acc       loss  val_acc   val_loss  \
# 90           softplus_Adagrad   0  0.097367  14.548733   0.0982  14.535301
# 119      hard_sigmoid_Adagrad   1  0.104417  14.435101   0.1028  14.461158
# 153     ThresholdedReLU_Nadam   1  0.112367   2.301160   0.1135   2.301005
# 118      hard_sigmoid_Adagrad   0  0.112367   2.301161   0.1135   2.301026
# 123       hard_sigmoid_Adamax   1  0.112367   2.301160   0.1135   2.301014
# 125        hard_sigmoid_Nadam   1  0.112367   2.301159   0.1135   2.301020
# 140      ThresholdedReLU_rmsp   0  0.112367   2.301160   0.1135   2.301009
# 141      ThresholdedReLU_rmsp   1  0.112367   2.301160   0.1135   2.301022
# 142      ThresholdedReLU_adam   0  0.112367   2.301159   0.1135   2.301016
# 143      ThresholdedReLU_adam   1  0.112367   2.301159   0.1135   2.301022
# 144       ThresholdedReLU_sgd   0  0.112367   2.301160   0.1135   2.301019
# 145       ThresholdedReLU_sgd   1  0.112367   2.301160   0.1135   2.301016
# 152     ThresholdedReLU_Nadam   0  0.112367   2.301227   0.1135   2.301008
# 147   ThresholdedReLU_Adagrad   1  0.112367   2.301160   0.1135   2.301024
# 146   ThresholdedReLU_Adagrad   0  0.112367   2.301160   0.1135   2.301023
# 151    ThresholdedReLU_Adamax   1  0.112367   2.301160   0.1135   2.301008
# 150    ThresholdedReLU_Adamax   0  0.112367   2.301160   0.1135   2.301019
# 149  ThresholdedReLU_Adadelta   1  0.112367   2.301159   0.1135   2.301010
# 148  ThresholdedReLU_Adadelta   0  0.112367   2.301160   0.1135   2.301020
# 117          hard_sigmoid_sgd   1  0.924600   0.263324   0.9290   0.246834
# 5                 sigmoid_sgd   1  0.932600   0.228403   0.9435   0.203249
# 4                 sigmoid_sgd   0  0.937900   0.213385   0.9460   0.188718
# 116          hard_sigmoid_sgd   0  0.944150   0.194358   0.9509   0.172671
# 7             sigmoid_Adagrad   1  0.961900   0.131039   0.9671   0.111607
# 6             sigmoid_Adagrad   0  0.962517   0.126899   0.9688   0.106558
# 91           softplus_Adagrad   1  0.973883   0.084745   0.9782   0.063512
# 55               linear_Nadam   1  0.998967   0.003432   0.9805   0.101368
# 54               linear_Nadam   0  0.998517   0.005263   0.9806   0.087437
# 124        hard_sigmoid_Nadam   0  0.979617   0.064966   0.9808   0.060866
# 44                linear_adam   0  0.997833   0.007887   0.9808   0.072608
# ..                        ...  ..       ...        ...      ...        ...
# 73                  selu_adam   1  0.996683   0.019169   0.9882   0.106243
# 135        LeakyReLU_Adadelta   1  0.997950   0.008075   0.9883   0.042616
# 127            LeakyReLU_rmsp   1  0.998900   0.004237   0.9883   0.053501
# 76               selu_Adagrad   0  0.992367   0.023708   0.9883   0.047568
# 95            softplus_Adamax   1  0.991950   0.024173   0.9883   0.040627
# 85              softplus_rmsp   1  0.988633   0.037740   0.9883   0.037909
# 106         softsign_Adadelta   0  0.996450   0.013752   0.9883   0.039954
# 129            LeakyReLU_adam   1  0.999750   0.001621   0.9885   0.053485
# 70                  selu_rmsp   0  0.995383   0.027178   0.9885   0.102608
# 82                 selu_Nadam   0  0.996117   0.044406   0.9885   0.145034
# 64               elu_Adadelta   0  0.996333   0.012957   0.9886   0.042172
# 96             softplus_Nadam   0  0.997300   0.007595   0.9888   0.049277
# 138           LeakyReLU_Nadam   0  0.999833   0.001222   0.9889   0.055808
# 128            LeakyReLU_adam   0  0.999517   0.002163   0.9891   0.049244
# 79              selu_Adadelta   1  0.996133   0.013684   0.9891   0.078257
# 87              softplus_adam   1  0.996267   0.012790   0.9891   0.043912
# 86              softplus_adam   0  0.996683   0.010281   0.9893   0.047903
# 34               relu_Adagrad   0  0.996500   0.013396   0.9894   0.034039
# 81                selu_Adamax   1  0.997233   0.008377   0.9895   0.070193
# 36              relu_Adadelta   0  0.995367   0.017100   0.9898   0.032469
# 35               relu_Adagrad   1  0.995933   0.013796   0.9898   0.034658
# 30                  relu_adam   0  0.999800   0.000857   0.9898   0.047404
# 39                relu_Adamax   1  0.999000   0.004127   0.9900   0.036094
# 38                relu_Adamax   0  0.999017   0.003273   0.9902   0.040813
# 41                 relu_Nadam   1  0.999950   0.000548   0.9906   0.052842
# 37              relu_Adadelta   1  0.997667   0.009572   0.9908   0.030753
# 29                  relu_rmsp   1  0.997150   0.009802   0.9909   0.033781
# 28                  relu_rmsp   0  0.996867   0.011434   0.9910   0.034243
# 40                 relu_Nadam   0  0.999933   0.000563   0.9912   0.049019
# 31                  relu_adam   1  0.999950   0.000570   0.9913   0.047317
#
#           opt              act
# 90    Adagrad         softplus
# 119   Adagrad     hard_sigmoid
# 153     Nadam  ThresholdedReLU
# 118   Adagrad     hard_sigmoid
# 123    Adamax     hard_sigmoid
# 125     Nadam     hard_sigmoid
# 140      rmsp  ThresholdedReLU
# 141      rmsp  ThresholdedReLU
# 142      adam  ThresholdedReLU
# 143      adam  ThresholdedReLU
# 144       sgd  ThresholdedReLU
# 145       sgd  ThresholdedReLU
# 152     Nadam  ThresholdedReLU
# 147   Adagrad  ThresholdedReLU
# 146   Adagrad  ThresholdedReLU
# 151    Adamax  ThresholdedReLU
# 150    Adamax  ThresholdedReLU
# 149  Adadelta  ThresholdedReLU
# 148  Adadelta  ThresholdedReLU
# 117       sgd     hard_sigmoid
# 5         sgd          sigmoid
# 4         sgd          sigmoid
# 116       sgd     hard_sigmoid
# 7     Adagrad          sigmoid
# 6     Adagrad          sigmoid
# 91    Adagrad         softplus
# 55      Nadam           linear
# 54      Nadam           linear
# 124     Nadam     hard_sigmoid
# 44       adam           linear
# ..        ...              ...
# 73       adam             selu
# 135  Adadelta        LeakyReLU
# 127      rmsp        LeakyReLU
# 76    Adagrad             selu
# 95     Adamax         softplus
# 85       rmsp         softplus
# 106  Adadelta         softsign
# 129      adam        LeakyReLU
# 70       rmsp             selu
# 82      Nadam             selu
# 64   Adadelta              elu
# 96      Nadam         softplus
# 138     Nadam        LeakyReLU
# 128      adam        LeakyReLU
# 79   Adadelta             selu
# 87       adam         softplus
# 86       adam         softplus
# 34    Adagrad             relu
# 81     Adamax             selu
# 36   Adadelta             relu
# 35    Adagrad             relu
# 30       adam             relu
# 39     Adamax             relu
# 38     Adamax             relu
# 41      Nadam             relu
# 37   Adadelta             relu
# 29       rmsp             relu
# 28       rmsp             relu
# 40      Nadam             relu
# 31       adam             relu
#
# [154 rows x 8 columns]

# %%
check = check.sort_values(by=['val_acc'])
check
# Out:
#                        config exp       acc       loss  val_acc   val_loss  \
# 90           softplus_Adagrad   0  0.097367  14.548733   0.0982  14.535301
# 119      hard_sigmoid_Adagrad   1  0.104417  14.435101   0.1028  14.461158
# 149  ThresholdedReLU_Adadelta   1  0.112367   2.301159   0.1135   2.301010
# 150    ThresholdedReLU_Adamax   0  0.112367   2.301160   0.1135   2.301019
# 151    ThresholdedReLU_Adamax   1  0.112367   2.301160   0.1135   2.301008
# 146   ThresholdedReLU_Adagrad   0  0.112367   2.301160   0.1135   2.301023
# 147   ThresholdedReLU_Adagrad   1  0.112367   2.301160   0.1135   2.301024
# 152     ThresholdedReLU_Nadam   0  0.112367   2.301227   0.1135   2.301008
# 145       ThresholdedReLU_sgd   1  0.112367   2.301160   0.1135   2.301016
# 144       ThresholdedReLU_sgd   0  0.112367   2.301160   0.1135   2.301019
# 148  ThresholdedReLU_Adadelta   0  0.112367   2.301160   0.1135   2.301020
# 142      ThresholdedReLU_adam   0  0.112367   2.301159   0.1135   2.301016
# 141      ThresholdedReLU_rmsp   1  0.112367   2.301160   0.1135   2.301022
# 140      ThresholdedReLU_rmsp   0  0.112367   2.301160   0.1135   2.301009
# 125        hard_sigmoid_Nadam   1  0.112367   2.301159   0.1135   2.301020
# 123       hard_sigmoid_Adamax   1  0.112367   2.301160   0.1135   2.301014
# 118      hard_sigmoid_Adagrad   0  0.112367   2.301161   0.1135   2.301026
# 153     ThresholdedReLU_Nadam   1  0.112367   2.301160   0.1135   2.301005
# 143      ThresholdedReLU_adam   1  0.112367   2.301159   0.1135   2.301022
# 117          hard_sigmoid_sgd   1  0.924600   0.263324   0.9290   0.246834
# 5                 sigmoid_sgd   1  0.932600   0.228403   0.9435   0.203249
# 4                 sigmoid_sgd   0  0.937900   0.213385   0.9460   0.188718
# 116          hard_sigmoid_sgd   0  0.944150   0.194358   0.9509   0.172671
# 7             sigmoid_Adagrad   1  0.961900   0.131039   0.9671   0.111607
# 6             sigmoid_Adagrad   0  0.962517   0.126899   0.9688   0.106558
# 91           softplus_Adagrad   1  0.973883   0.084745   0.9782   0.063512
# 55               linear_Nadam   1  0.998967   0.003432   0.9805   0.101368
# 54               linear_Nadam   0  0.998517   0.005263   0.9806   0.087437
# 124        hard_sigmoid_Nadam   0  0.979617   0.064966   0.9808   0.060866
# 44                linear_adam   0  0.997833   0.007887   0.9808   0.072608
# ..                        ...  ..       ...        ...      ...        ...
# 73                  selu_adam   1  0.996683   0.019169   0.9882   0.106243
# 106         softsign_Adadelta   0  0.996450   0.013752   0.9883   0.039954
# 135        LeakyReLU_Adadelta   1  0.997950   0.008075   0.9883   0.042616
# 127            LeakyReLU_rmsp   1  0.998900   0.004237   0.9883   0.053501
# 76               selu_Adagrad   0  0.992367   0.023708   0.9883   0.047568
# 95            softplus_Adamax   1  0.991950   0.024173   0.9883   0.040627
# 85              softplus_rmsp   1  0.988633   0.037740   0.9883   0.037909
# 82                 selu_Nadam   0  0.996117   0.044406   0.9885   0.145034
# 70                  selu_rmsp   0  0.995383   0.027178   0.9885   0.102608
# 129            LeakyReLU_adam   1  0.999750   0.001621   0.9885   0.053485
# 64               elu_Adadelta   0  0.996333   0.012957   0.9886   0.042172
# 96             softplus_Nadam   0  0.997300   0.007595   0.9888   0.049277
# 138           LeakyReLU_Nadam   0  0.999833   0.001222   0.9889   0.055808
# 128            LeakyReLU_adam   0  0.999517   0.002163   0.9891   0.049244
# 79              selu_Adadelta   1  0.996133   0.013684   0.9891   0.078257
# 87              softplus_adam   1  0.996267   0.012790   0.9891   0.043912
# 86              softplus_adam   0  0.996683   0.010281   0.9893   0.047903
# 34               relu_Adagrad   0  0.996500   0.013396   0.9894   0.034039
# 81                selu_Adamax   1  0.997233   0.008377   0.9895   0.070193
# 36              relu_Adadelta   0  0.995367   0.017100   0.9898   0.032469
# 35               relu_Adagrad   1  0.995933   0.013796   0.9898   0.034658
# 30                  relu_adam   0  0.999800   0.000857   0.9898   0.047404
# 39                relu_Adamax   1  0.999000   0.004127   0.9900   0.036094
# 38                relu_Adamax   0  0.999017   0.003273   0.9902   0.040813
# 41                 relu_Nadam   1  0.999950   0.000548   0.9906   0.052842
# 37              relu_Adadelta   1  0.997667   0.009572   0.9908   0.030753
# 29                  relu_rmsp   1  0.997150   0.009802   0.9909   0.033781
# 28                  relu_rmsp   0  0.996867   0.011434   0.9910   0.034243
# 40                 relu_Nadam   0  0.999933   0.000563   0.9912   0.049019
# 31                  relu_adam   1  0.999950   0.000570   0.9913   0.047317
#
#           opt              act
# 90    Adagrad         softplus
# 119   Adagrad     hard_sigmoid
# 149  Adadelta  ThresholdedReLU
# 150    Adamax  ThresholdedReLU
# 151    Adamax  ThresholdedReLU
# 146   Adagrad  ThresholdedReLU
# 147   Adagrad  ThresholdedReLU
# 152     Nadam  ThresholdedReLU
# 145       sgd  ThresholdedReLU
# 144       sgd  ThresholdedReLU
# 148  Adadelta  ThresholdedReLU
# 142      adam  ThresholdedReLU
# 141      rmsp  ThresholdedReLU
# 140      rmsp  ThresholdedReLU
# 125     Nadam     hard_sigmoid
# 123    Adamax     hard_sigmoid
# 118   Adagrad     hard_sigmoid
# 153     Nadam  ThresholdedReLU
# 143      adam  ThresholdedReLU
# 117       sgd     hard_sigmoid
# 5         sgd          sigmoid
# 4         sgd          sigmoid
# 116       sgd     hard_sigmoid
# 7     Adagrad          sigmoid
# 6     Adagrad          sigmoid
# 91    Adagrad         softplus
# 55      Nadam           linear
# 54      Nadam           linear
# 124     Nadam     hard_sigmoid
# 44       adam           linear
# ..        ...              ...
# 73       adam             selu
# 106  Adadelta         softsign
# 135  Adadelta        LeakyReLU
# 127      rmsp        LeakyReLU
# 76    Adagrad             selu
# 95     Adamax         softplus
# 85       rmsp         softplus
# 82      Nadam             selu
# 70       rmsp             selu
# 129      adam        LeakyReLU
# 64   Adadelta              elu
# 96      Nadam         softplus
# 138     Nadam        LeakyReLU
# 128      adam        LeakyReLU
# 79   Adadelta             selu
# 87       adam         softplus
# 86       adam         softplus
# 34    Adagrad             relu
# 81     Adamax             selu
# 36   Adadelta             relu
# 35    Adagrad             relu
# 30       adam             relu
# 39     Adamax             relu
# 38     Adamax             relu
# 41      Nadam             relu
# 37   Adadelta             relu
# 29       rmsp             relu
# 28       rmsp             relu
# 40      Nadam             relu
# 31       adam             relu
#
# [154 rows x 8 columns]

# %%
for d in range(len(data)):
    max_acc = 0 
    max_val_acc = 0
    min_loss = 100
    min_val_loss = 100
    val_acc_diff = 0.
    
    min_val_acc_diff_10 = 1.
    min_val_acc_diff_epoch = 0
    
    has_hit = False

    for epoch in range(epochs):
        acc = []
        loss = []
        val_acc = []
        val_loss = []
        val_acc_diffs = []
        
        for experiment in range(experiments):
            acc.append(data[d]['data'][experiment].iloc[epoch]['acc'])
            loss.append(data[d]['data'][experiment].iloc[epoch]['loss'])
            val_acc.append(data[d]['data'][experiment].iloc[epoch]['val_acc'])
            val_loss.append(data[d]['data'][experiment].iloc[epoch]['val_loss'])
            if epoch > 0:
                val_acc_diffs.append(data[d]['data'][experiment].iloc[epoch]['val_acc'] - data[d]['data'][experiment].iloc[epoch-1]['val_acc'])
            else:
                val_acc_diffs.append(0)
        
        av_acc = sum(acc)/len(acc)
        av_loss = sum(loss)/len(loss)
        av_val_acc = sum(val_acc)/len(val_acc)
        av_val_loss = sum(val_loss)/len(val_loss)
        av_val_acc_diffs = sum(val_acc_diffs)/len(val_acc_diffs)
        std = np.std(val_acc)

        if(av_acc > max_acc):
            max_acc = av_acc
            data[d]['best']['max_acc'] = max_acc
            data[d]['best']['max_acc_epoch'] = epoch
        
#         if(av_val_acc > max_val_acc):
#             max_val_acc = av_val_acc
#             data[d]['best']['max_val_acc'] = max_acc
#             data[d]['best']['max_val_acc_epoch'] = epoch+1
        
        if(av_loss < min_loss):
            min_loss = av_loss
            data[d]['best']['min_loss'] = min_loss
            data[d]['best']['min_loss_epoch'] = epoch
        
        if(av_val_loss < min_val_loss):
            min_val_loss = av_val_loss
            data[d]['best']['min_val_loss'] = min_val_loss
            data[d]['best']['min_val_loss_epoch'] = epoch
        
        
        
        data[d]['averaged'] = data[d]['averaged'].append({
            'epoch': epoch,
            'acc': (av_acc),
            'loss': (av_loss),
            'val_acc': (av_val_acc),
            'val_loss': (av_val_loss),
            'val_acc_diff' : av_val_acc_diffs,
            'val_acc_std': std}, ignore_index=True)
        
        if epoch>5:
            av_val_acc_diff_10 = np.mean(np.absolute(data[d]['averaged'].iloc[epoch-6:epoch]['val_acc_diff'].values))
            
            if av_val_acc_diff_10 < 0.00005 and av_val_acc > max_val_acc:
                max_val_acc = av_val_acc
                data[d]['best']['max_val_acc'] = max_acc
                data[d]['best']['max_val_acc_epoch'] = epoch
                has_hit = True
#                 print('Config: ' + data[d]['disp_name'] + ', epoch: ' + str(epoch) + ', val_acc: '+ str(av_val_acc) +', diff: ' + str(av_val_acc_diffs) + ', av_diff: ' + str(av_val_acc_diff_10) + ' HIT!')
#             else:
#                 print('Config: ' + data[d]['disp_name'] + ', epoch: ' + str(epoch) + ', val_acc: '+ str(av_val_acc) +', diff: ' + str(av_val_acc_diffs) + ', av_diff: ' + str(av_val_acc_diff_10))
    if not has_hit:
        data[d]['best']['max_val_acc'] = data[d]['averaged'].iloc[epochs-1]['val_acc']
        data[d]['best']['max_val_acc_epoch'] = epochs
        print('Config: ' + data[d]['disp_name'] + ' had no hits, max val_acc: '+ str(data[d]['best']['max_val_acc']) +' at epoch ' + str(data[d]['best']['max_val_acc_epoch']))
    else:
        print('Config: ' + data[d]['disp_name'] + ' HAD HITS, max val_acc: '+ str(data[d]['best']['max_val_acc']) +' at epoch ' + str(data[d]['best']['max_val_acc_epoch']))
# Out:
# Config: sigmoid_rmsp had no hits, max val_acc: 0.98595 at epoch 40
# Config: sigmoid_adam had no hits, max val_acc: 0.9874499999999999 at epoch 40
# Config: sigmoid_sgd had no hits, max val_acc: 0.94475 at epoch 40
# Config: sigmoid_Adagrad had no hits, max val_acc: 0.96795 at epoch 40
# Config: sigmoid_Adadelta HAD HITS, max val_acc: 0.98905 at epoch 39
# Config: sigmoid_Adamax had no hits, max val_acc: 0.9872000000000001 at epoch 40
# Config: sigmoid_Nadam had no hits, max val_acc: 0.987 at epoch 40
# Config: tanh_rmsp HAD HITS, max val_acc: 0.9991999999998333 at epoch 33
# Config: tanh_adam HAD HITS, max val_acc: 0.9992833333335001 at epoch 38
# Config: tanh_sgd had no hits, max val_acc: 0.9841 at epoch 40
# Config: tanh_Adagrad HAD HITS, max val_acc: 0.9948083333333334 at epoch 35
# Config: tanh_Adadelta HAD HITS, max val_acc: 0.9982333333333333 at epoch 33
# Config: tanh_Adamax HAD HITS, max val_acc: 0.9991083333335 at epoch 35
# Config: tanh_Nadam had no hits, max val_acc: 0.9834 at epoch 40
# Config: relu_rmsp HAD HITS, max val_acc: 0.9972083333333335 at epoch 33
# Config: relu_adam HAD HITS, max val_acc: 0.9999000000001667 at epoch 29
# Config: relu_sgd had no hits, max val_acc: 0.98695 at epoch 40
# Config: relu_Adagrad HAD HITS, max val_acc: 0.996325 at epoch 30
# Config: relu_Adadelta had no hits, max val_acc: 0.9903 at epoch 40
# Config: relu_Adamax HAD HITS, max val_acc: 0.9992000000000001 at epoch 35
# Config: relu_Nadam HAD HITS, max val_acc: 0.9999666666668334 at epoch 33
# Config: linear_rmsp HAD HITS, max val_acc: 0.9969666666666667 at epoch 36
# Config: linear_adam HAD HITS, max val_acc: 0.9978333333335001 at epoch 32
# Config: linear_sgd had no hits, max val_acc: 0.9829 at epoch 40
# Config: linear_Adagrad HAD HITS, max val_acc: 0.9927333333335 at epoch 33
# Config: linear_Adadelta HAD HITS, max val_acc: 0.99475 at epoch 39
# Config: linear_Adamax HAD HITS, max val_acc: 0.9973999999998333 at epoch 38
# Config: linear_Nadam HAD HITS, max val_acc: 0.9988833333331666 at epoch 32
# Config: elu_rmsp HAD HITS, max val_acc: 0.998575 at epoch 37
# Config: elu_adam HAD HITS, max val_acc: 0.9994916666668333 at epoch 39
# Config: elu_sgd HAD HITS, max val_acc: 0.9878833333333334 at epoch 39
# Config: elu_Adagrad HAD HITS, max val_acc: 0.9943666666665 at epoch 39
# Config: elu_Adadelta HAD HITS, max val_acc: 0.9971833333335001 at epoch 33
# Config: elu_Adamax HAD HITS, max val_acc: 0.99865 at epoch 31
# Config: elu_Nadam HAD HITS, max val_acc: 0.9990083333335 at epoch 36
# Config: selu_rmsp HAD HITS, max val_acc: 0.9958333333333333 at epoch 37
# Config: selu_adam had no hits, max val_acc: 0.988 at epoch 40
# Config: selu_sgd had no hits, max val_acc: 0.98705 at epoch 40
# Config: selu_Adagrad HAD HITS, max val_acc: 0.9916333333333334 at epoch 34
# Config: selu_Adadelta had no hits, max val_acc: 0.98815 at epoch 40
# Config: selu_Adamax had no hits, max val_acc: 0.9886 at epoch 40
# Config: selu_Nadam had no hits, max val_acc: 0.98785 at epoch 40
# Config: softplus_rmsp had no hits, max val_acc: 0.9876 at epoch 40
# Config: softplus_adam had no hits, max val_acc: 0.9892 at epoch 40
# Config: softplus_sgd had no hits, max val_acc: 0.9854 at epoch 40
# Config: softplus_Adagrad had no hits, max val_acc: 0.5382 at epoch 40
# Config: softplus_Adadelta HAD HITS, max val_acc: 0.9884166666668335 at epoch 39
# Config: softplus_Adamax had no hits, max val_acc: 0.988 at epoch 40
# Config: softplus_Nadam had no hits, max val_acc: 0.98845 at epoch 40
# Config: softsign_rmsp HAD HITS, max val_acc: 0.9991416666668334 at epoch 36
# Config: softsign_adam HAD HITS, max val_acc: 0.9988250000001667 at epoch 36
# Config: softsign_sgd had no hits, max val_acc: 0.98175 at epoch 40
# Config: softsign_Adagrad HAD HITS, max val_acc: 0.9935416666668333 at epoch 26
# Config: softsign_Adadelta HAD HITS, max val_acc: 0.9970083333331665 at epoch 33
# Config: softsign_Adamax had no hits, max val_acc: 0.98665 at epoch 40
# Config: softsign_Nadam had no hits, max val_acc: 0.9853 at epoch 40
# Config: hard_sigmoid_rmsp had no hits, max val_acc: 0.98675 at epoch 40
# Config: hard_sigmoid_adam had no hits, max val_acc: 0.98355 at epoch 40
# Config: hard_sigmoid_sgd had no hits, max val_acc: 0.9399500000000001 at epoch 40
# Config: hard_sigmoid_Adagrad HAD HITS, max val_acc: 0.10839166666683334 at epoch 6
# Config: hard_sigmoid_Adadelta had no hits, max val_acc: 0.98695 at epoch 40
# Config: hard_sigmoid_Adamax had no hits, max val_acc: 0.5478 at epoch 40
# Config: hard_sigmoid_Nadam had no hits, max val_acc: 0.54715 at epoch 40
# Config: LeakyReLU_rmsp HAD HITS, max val_acc: 0.9988416666668334 at epoch 35
# Config: LeakyReLU_adam HAD HITS, max val_acc: 0.999725 at epoch 39
# Config: LeakyReLU_sgd had no hits, max val_acc: 0.98575 at epoch 40
# Config: LeakyReLU_Adagrad HAD HITS, max val_acc: 0.9960916666666666 at epoch 32
# Config: LeakyReLU_Adadelta HAD HITS, max val_acc: 0.9957666666664999 at epoch 31
# Config: LeakyReLU_Adamax HAD HITS, max val_acc: 0.9982333333331667 at epoch 33
# Config: LeakyReLU_Nadam HAD HITS, max val_acc: 0.9998833333331667 at epoch 39
# Config: ThresholdedReLU_rmsp HAD HITS, max val_acc: 0.11236666666683334 at epoch 6
# Config: ThresholdedReLU_adam HAD HITS, max val_acc: 0.11236666666683334 at epoch 6
# Config: ThresholdedReLU_sgd HAD HITS, max val_acc: 0.11236666666683334 at epoch 6
# Config: ThresholdedReLU_Adagrad HAD HITS, max val_acc: 0.11236666666683334 at epoch 6
# Config: ThresholdedReLU_Adadelta HAD HITS, max val_acc: 0.11236666666683334 at epoch 6
# Config: ThresholdedReLU_Adamax HAD HITS, max val_acc: 0.11236666666683334 at epoch 6
# Config: ThresholdedReLU_Nadam HAD HITS, max val_acc: 0.11236666666666667 at epoch 6

# %%
results = pd.DataFrame(columns=['config', 'acc', 'loss', 'val_acc','val_acc_std', 'val_loss', 'opt', 'act', 'max_acc_epoch', 'max_val_acc_epoch', 'min_loss_epoch', 'min_val_loss_epoch'])
i=0
for d in data:
    results.loc[i] = [d['disp_name'], 
                      d['averaged']['acc'].tolist()[-1], 
                      d['averaged']['loss'].tolist()[-1], 
                      d['averaged']['val_acc'].tolist()[-1], 
                      d['averaged']['val_acc_std'].tolist()[-1],
                      d['averaged']['val_loss'].tolist()[-1], 
                      d['opt'], 
                      d['act'],
                      d['best']['max_acc_epoch'],
                     d['best']['max_val_acc_epoch'],
                     d['best']['min_loss_epoch'],
                     d['best']['min_val_loss_epoch'],]
    i+=1

# %%
results
# Out:
#                       config       acc      loss  val_acc  val_acc_std  \
# 0               sigmoid_rmsp  0.989117  0.037744  0.98595      0.00015
# 1               sigmoid_adam  0.993783  0.020343  0.98745      0.00015
# 2                sigmoid_sgd  0.935250  0.220894  0.94475      0.00125
# 3            sigmoid_Adagrad  0.962208  0.128969  0.96795      0.00085
# 4           sigmoid_Adadelta  0.988692  0.037442  0.98615      0.00025
# 5             sigmoid_Adamax  0.993342  0.022312  0.98720      0.00030
# 6              sigmoid_Nadam  0.996150  0.013087  0.98700      0.00070
# 7                  tanh_rmsp  0.999208  0.003431  0.98535      0.00045
# 8                  tanh_adam  0.999033  0.003276  0.98465      0.00095
# 9                   tanh_sgd  0.986633  0.046166  0.98410      0.00050
# 10              tanh_Adagrad  0.994567  0.020113  0.98605      0.00015
# 11             tanh_Adadelta  0.998217  0.007370  0.98685      0.00005
# 12               tanh_Adamax  0.999042  0.004561  0.98715      0.00005
# 13                tanh_Nadam  0.999358  0.002564  0.98340      0.00030
# 14                 relu_rmsp  0.997008  0.010618  0.99095      0.00005
# 15                 relu_adam  0.999875  0.000714  0.99055      0.00075
# 16                  relu_sgd  0.988567  0.037533  0.98695      0.00045
# 17              relu_Adagrad  0.996217  0.013596  0.98960      0.00020
# 18             relu_Adadelta  0.996517  0.013336  0.99030      0.00050
# 19               relu_Adamax  0.999008  0.003700  0.99010      0.00010
# 20                relu_Nadam  0.999942  0.000556  0.99090      0.00030
# 21               linear_rmsp  0.996858  0.011363  0.98245      0.00035
# 22               linear_adam  0.997642  0.008563  0.98140      0.00060
# 23                linear_sgd  0.986400  0.045110  0.98290      0.00070
# 24            linear_Adagrad  0.992517  0.026243  0.98405      0.00045
# 25           linear_Adadelta  0.994550  0.019373  0.98410      0.00020
# 26             linear_Adamax  0.997233  0.009907  0.98230      0.00020
# 27              linear_Nadam  0.998742  0.004347  0.98055      0.00005
# 28                  elu_rmsp  0.998450  0.005777  0.98665      0.00005
# 29                  elu_adam  0.999442  0.002010  0.98635      0.00015
# ..                       ...       ...       ...      ...          ...
# 47           softplus_Adamax  0.991625  0.025052  0.98800      0.00030
# 48            softplus_Nadam  0.996192  0.010970  0.98845      0.00035
# 49             softsign_rmsp  0.999183  0.003424  0.98625      0.00015
# 50             softsign_adam  0.998725  0.005240  0.98620      0.00070
# 51              softsign_sgd  0.982583  0.060611  0.98175      0.00035
# 52          softsign_Adagrad  0.993192  0.023831  0.98690      0.00040
# 53         softsign_Adadelta  0.996767  0.012130  0.98760      0.00070
# 54           softsign_Adamax  0.997683  0.009645  0.98665      0.00075
# 55            softsign_Nadam  0.999458  0.002336  0.98530      0.00000
# 56         hard_sigmoid_rmsp  0.989667  0.034955  0.98675      0.00065
# 57         hard_sigmoid_adam  0.982492  0.054867  0.98355      0.00095
# 58          hard_sigmoid_sgd  0.934375  0.228841  0.93995      0.01095
# 59      hard_sigmoid_Adagrad  0.108392  8.368131  0.10815      0.00535
# 60     hard_sigmoid_Adadelta  0.991533  0.028907  0.98695      0.00075
# 61       hard_sigmoid_Adamax  0.543442  1.190867  0.54780      0.43430
# 62        hard_sigmoid_Nadam  0.545992  1.183063  0.54715      0.43365
# 63            LeakyReLU_rmsp  0.998792  0.004526  0.98800      0.00030
# 64            LeakyReLU_adam  0.999633  0.001892  0.98880      0.00030
# 65             LeakyReLU_sgd  0.986825  0.043798  0.98575      0.00005
# 66         LeakyReLU_Adagrad  0.995992  0.015074  0.98740      0.00030
# 67        LeakyReLU_Adadelta  0.995608  0.015850  0.98765      0.00065
# 68          LeakyReLU_Adamax  0.998317  0.007043  0.98795      0.00015
# 69           LeakyReLU_Nadam  0.999842  0.001276  0.98830      0.00060
# 70      ThresholdedReLU_rmsp  0.112367  2.301160  0.11350      0.00000
# 71      ThresholdedReLU_adam  0.112367  2.301159  0.11350      0.00000
# 72       ThresholdedReLU_sgd  0.112367  2.301160  0.11350      0.00000
# 73   ThresholdedReLU_Adagrad  0.112367  2.301160  0.11350      0.00000
# 74  ThresholdedReLU_Adadelta  0.112367  2.301159  0.11350      0.00000
# 75    ThresholdedReLU_Adamax  0.112367  2.301160  0.11350      0.00000
# 76     ThresholdedReLU_Nadam  0.112367  2.301193  0.11350      0.00000
#
#     val_loss       opt              act max_acc_epoch max_val_acc_epoch  \
# 0   0.043256      rmsp          sigmoid            39                40
# 1   0.044014      adam          sigmoid            32                40
# 2   0.195983       sgd          sigmoid            38                40
# 3   0.109082   Adagrad          sigmoid            38                40
# 4   0.043468  Adadelta          sigmoid            34                39
# 5   0.042756    Adamax          sigmoid            38                40
# 6   0.047434     Nadam          sigmoid            39                40
# 7   0.072951      rmsp             tanh            39                33
# 8   0.078167      adam             tanh            29                38
# 9   0.049474       sgd             tanh            37                40
# 10  0.044873   Adagrad             tanh            32                35
# 11  0.047057  Adadelta             tanh            34                33
# 12  0.051733    Adamax             tanh            34                35
# 13  0.101519     Nadam             tanh            30                40
# 14  0.034012      rmsp             relu            27                33
# 15  0.047360      adam             relu            33                29
# 16  0.040202       sgd             relu            36                40
# 17  0.034349   Adagrad             relu            36                30
# 18  0.031611  Adadelta             relu            36                40
# 19  0.038453    Adamax             relu            36                35
# 20  0.050930     Nadam             relu            26                33
# 21  0.073513      rmsp           linear            31                36
# 22  0.072007      adam           linear            29                32
# 23  0.051380       sgd           linear            37                40
# 24  0.052022   Adagrad           linear            33                33
# 25  0.057806  Adadelta           linear            30                39
# 26  0.069029    Adamax           linear            38                38
# 27  0.094403     Nadam           linear            33                32
# 28  0.065727      rmsp              elu            32                37
# 29  0.075654      adam              elu            38                39
# ..       ...       ...              ...           ...               ...
# 47  0.043478    Adamax         softplus            38                40
# 48  0.047207     Nadam         softplus            36                40
# 49  0.065608      rmsp         softsign            39                36
# 50  0.058172      adam         softsign            38                36
# 51  0.060373       sgd         softsign            39                40
# 52  0.041972   Adagrad         softsign            29                26
# 53  0.042128  Adadelta         softsign            33                33
# 54  0.047170    Adamax         softsign            36                40
# 55  0.089562     Nadam         softsign            30                40
# 56  0.042015      rmsp     hard_sigmoid            33                40
# 57  0.051467      adam     hard_sigmoid            34                40
# 58  0.209752       sgd     hard_sigmoid            39                40
# 59  8.381092   Adagrad     hard_sigmoid             1                 6
# 60  0.043124  Adadelta     hard_sigmoid            37                40
# 61  1.181297    Adamax     hard_sigmoid            37                40
# 62  1.180943     Nadam     hard_sigmoid            39                40
# 63  0.052813      rmsp        LeakyReLU            29                35
# 64  0.051364      adam        LeakyReLU            29                39
# 65  0.043294       sgd        LeakyReLU            38                40
# 66  0.041348   Adagrad        LeakyReLU            35                32
# 67  0.041028  Adadelta        LeakyReLU            31                31
# 68  0.044167    Adamax        LeakyReLU            39                33
# 69  0.054539     Nadam        LeakyReLU            31                39
# 70  2.301015      rmsp  ThresholdedReLU             1                 6
# 71  2.301019      adam  ThresholdedReLU             1                 6
# 72  2.301018       sgd  ThresholdedReLU             1                 6
# 73  2.301023   Adagrad  ThresholdedReLU             1                 6
# 74  2.301015  Adadelta  ThresholdedReLU             1                 6
# 75  2.301014    Adamax  ThresholdedReLU             1                 6
# 76  2.301006     Nadam  ThresholdedReLU             1                 6
#
#    min_loss_epoch min_val_loss_epoch
# 0              39                 27
# 1              36                 28
# 2              38                 39
# 3              39                 39
# 4              31                 27
# 5              38                 39
# 6              36                 19
# 7              39                  4
# 8              35                  4
# 9              39                 37
# 10             32                 22
# 11             39                 13
# 12             34                  5
# 13             37                  1
# 14             38                  9
# 15             36                  5
# 16             36                 37
# 17             36                  9
# 18             37                 19
# 19             36                  8
# 20             36                  2
# 21             25                  3
# 22             37                  2
# 23             37                 30
# 24             28                 12
# 25             31                 11
# 26             36                  3
# 27             34                  3
# 28             37                  3
# 29             39                  4
# ..            ...                ...
# 47             38                 37
# 48             32                 13
# 49             32                  4
# 50             38                 21
# 51             39                 39
# 52             32                 27
# 53             31                 24
# 54             32                 23
# 55             39                  3
# 56             39                 37
# 57             38                 36
# 58             39                 39
# 59             38                 23
# 60             38                 27
# 61             39                 39
# 62             36                 35
# 63             39                  5
# 64             38                  3
# 65             39                 39
# 66             31                 18
# 67             33                 12
# 68             39                  6
# 69             26                  8
# 70             31                  9
# 71             39                 10
# 72             34                  7
# 73             31                 30
# 74             38                  4
# 75             30                  4
# 76             33                  9
#
# [77 rows x 12 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
def get_cmap(n, name='hsv'):
    '''Returns a function that maps each index in 0, 1, ..., n-1 to a distinct 
    RGB color; the keyword argument name must be a standard mpl colormap name.'''
    return plt.cm.get_cmap(name, n)

# %%
plt.figure(figsize=(20,10))
cmap = get_cmap(experiments * 2)
for d in data:
    plt.plot(range(epochs),
             d['averaged']['loss'].tolist(),
             d['col'],
             linestyle=d['line'],
             label=d['disp_name'] + ' Loss')
    plt.annotate('%0.4f' % d['averaged']['loss'].tolist()[-1], xy=(1, d['averaged']['loss'].tolist()[-1]), xytext=(8, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.yscale('log')
plt.legend(loc='upper center',ncol=2)

# %%
plt.figure(figsize=(20,10))
cmap = get_cmap(experiments * 2)
for d in data:
    plt.plot(range(epochs-5,epochs),
             d['averaged']['loss'].tolist()[epochs-5:],
             d['col'],
             linestyle=d['line'],
             label=d['disp_name'] + ' Loss')
    plt.annotate('%0.4f' % d['averaged']['loss'].tolist()[-1], xy=(1, d['averaged']['loss'].tolist()[-1]), xytext=(8, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.yscale('log')
plt.legend(loc='center left',ncol=2)

# %%
sorted_by_loss = results.sort_values(by=['loss'])
sorted_by_loss
# Out:
#                       config       acc      loss  val_acc  val_acc_std  \
# 20                relu_Nadam  0.999942  0.000556  0.99090      0.00030
# 15                 relu_adam  0.999875  0.000714  0.99055      0.00075
# 69           LeakyReLU_Nadam  0.999842  0.001276  0.98830      0.00060
# 64            LeakyReLU_adam  0.999633  0.001892  0.98880      0.00030
# 29                  elu_adam  0.999442  0.002010  0.98635      0.00015
# 55            softsign_Nadam  0.999458  0.002336  0.98530      0.00000
# 13                tanh_Nadam  0.999358  0.002564  0.98340      0.00030
# 8                  tanh_adam  0.999033  0.003276  0.98465      0.00095
# 49             softsign_rmsp  0.999183  0.003424  0.98625      0.00015
# 7                  tanh_rmsp  0.999208  0.003431  0.98535      0.00045
# 19               relu_Adamax  0.999008  0.003700  0.99010      0.00010
# 34                 elu_Nadam  0.998942  0.003902  0.98560      0.00010
# 27              linear_Nadam  0.998742  0.004347  0.98055      0.00005
# 63            LeakyReLU_rmsp  0.998792  0.004526  0.98800      0.00030
# 12               tanh_Adamax  0.999042  0.004561  0.98715      0.00005
# 33                elu_Adamax  0.998617  0.005189  0.98730      0.00020
# 50             softsign_adam  0.998725  0.005240  0.98620      0.00070
# 28                  elu_rmsp  0.998450  0.005777  0.98665      0.00005
# 68          LeakyReLU_Adamax  0.998317  0.007043  0.98795      0.00015
# 11             tanh_Adadelta  0.998217  0.007370  0.98685      0.00005
# 40               selu_Adamax  0.997500  0.007449  0.98860      0.00090
# 22               linear_adam  0.997642  0.008563  0.98140      0.00060
# 54           softsign_Adamax  0.997683  0.009645  0.98665      0.00075
# 26             linear_Adamax  0.997233  0.009907  0.98230      0.00020
# 14                 relu_rmsp  0.997008  0.010618  0.99095      0.00005
# 32              elu_Adadelta  0.996975  0.010923  0.98770      0.00090
# 48            softplus_Nadam  0.996192  0.010970  0.98845      0.00035
# 21               linear_rmsp  0.996858  0.011363  0.98245      0.00035
# 43             softplus_adam  0.996475  0.011536  0.98920      0.00010
# 39             selu_Adadelta  0.996717  0.011910  0.98815      0.00095
# ..                       ...       ...       ...      ...          ...
# 60     hard_sigmoid_Adadelta  0.991533  0.028907  0.98695      0.00075
# 37                  selu_sgd  0.990000  0.032480  0.98705      0.00065
# 56         hard_sigmoid_rmsp  0.989667  0.034955  0.98675      0.00065
# 4           sigmoid_Adadelta  0.988692  0.037442  0.98615      0.00025
# 16                  relu_sgd  0.988567  0.037533  0.98695      0.00045
# 0               sigmoid_rmsp  0.989117  0.037744  0.98595      0.00015
# 46         softplus_Adadelta  0.988417  0.039039  0.98695      0.00115
# 42             softplus_rmsp  0.988325  0.039041  0.98760      0.00070
# 30                   elu_sgd  0.987617  0.041487  0.98560      0.00030
# 65             LeakyReLU_sgd  0.986825  0.043798  0.98575      0.00005
# 23                linear_sgd  0.986400  0.045110  0.98290      0.00070
# 9                   tanh_sgd  0.986633  0.046166  0.98410      0.00050
# 44              softplus_sgd  0.984158  0.050447  0.98540      0.00070
# 57         hard_sigmoid_adam  0.982492  0.054867  0.98355      0.00095
# 41                selu_Nadam  0.995275  0.060551  0.98785      0.00065
# 51              softsign_sgd  0.982583  0.060611  0.98175      0.00035
# 3            sigmoid_Adagrad  0.962208  0.128969  0.96795      0.00085
# 2                sigmoid_sgd  0.935250  0.220894  0.94475      0.00125
# 58          hard_sigmoid_sgd  0.934375  0.228841  0.93995      0.01095
# 62        hard_sigmoid_Nadam  0.545992  1.183063  0.54715      0.43365
# 61       hard_sigmoid_Adamax  0.543442  1.190867  0.54780      0.43430
# 71      ThresholdedReLU_adam  0.112367  2.301159  0.11350      0.00000
# 74  ThresholdedReLU_Adadelta  0.112367  2.301159  0.11350      0.00000
# 72       ThresholdedReLU_sgd  0.112367  2.301160  0.11350      0.00000
# 70      ThresholdedReLU_rmsp  0.112367  2.301160  0.11350      0.00000
# 73   ThresholdedReLU_Adagrad  0.112367  2.301160  0.11350      0.00000
# 75    ThresholdedReLU_Adamax  0.112367  2.301160  0.11350      0.00000
# 76     ThresholdedReLU_Nadam  0.112367  2.301193  0.11350      0.00000
# 45          softplus_Adagrad  0.535625  7.316739  0.53820      0.44000
# 59      hard_sigmoid_Adagrad  0.108392  8.368131  0.10815      0.00535
#
#     val_loss       opt              act max_acc_epoch max_val_acc_epoch  \
# 20  0.050930     Nadam             relu            26                33
# 15  0.047360      adam             relu            33                29
# 69  0.054539     Nadam        LeakyReLU            31                39
# 64  0.051364      adam        LeakyReLU            29                39
# 29  0.075654      adam              elu            38                39
# 55  0.089562     Nadam         softsign            30                40
# 13  0.101519     Nadam             tanh            30                40
# 8   0.078167      adam             tanh            29                38
# 49  0.065608      rmsp         softsign            39                36
# 7   0.072951      rmsp             tanh            39                33
# 19  0.038453    Adamax             relu            36                35
# 34  0.076594     Nadam              elu            33                36
# 27  0.094403     Nadam           linear            33                32
# 63  0.052813      rmsp        LeakyReLU            29                35
# 12  0.051733    Adamax             tanh            34                35
# 33  0.055672    Adamax              elu            36                31
# 50  0.058172      adam         softsign            38                36
# 28  0.065727      rmsp              elu            32                37
# 68  0.044167    Adamax        LeakyReLU            39                33
# 11  0.047057  Adadelta             tanh            34                33
# 40  0.074837    Adamax             selu            38                40
# 22  0.072007      adam           linear            29                32
# 54  0.047170    Adamax         softsign            36                40
# 26  0.069029    Adamax           linear            38                38
# 14  0.034012      rmsp             relu            27                33
# 32  0.046143  Adadelta              elu            34                33
# 48  0.047207     Nadam         softplus            36                40
# 21  0.073513      rmsp           linear            31                36
# 43  0.045908      adam         softplus            39                40
# 39  0.083277  Adadelta             selu            37                40
# ..       ...       ...              ...           ...               ...
# 60  0.043124  Adadelta     hard_sigmoid            37                40
# 37  0.045984       sgd             selu            38                40
# 56  0.042015      rmsp     hard_sigmoid            33                40
# 4   0.043468  Adadelta          sigmoid            34                39
# 16  0.040202       sgd             relu            36                40
# 0   0.043256      rmsp          sigmoid            39                40
# 46  0.042587  Adadelta         softplus            39                39
# 42  0.040711      rmsp         softplus            36                40
# 30  0.044514       sgd              elu            35                39
# 65  0.043294       sgd        LeakyReLU            38                40
# 23  0.051380       sgd           linear            37                40
# 9   0.049474       sgd             tanh            37                40
# 44  0.046033       sgd         softplus            37                40
# 57  0.051467      adam     hard_sigmoid            34                40
# 41  0.167950     Nadam             selu            38                40
# 51  0.060373       sgd         softsign            39                40
# 3   0.109082   Adagrad          sigmoid            38                40
# 2   0.195983       sgd          sigmoid            38                40
# 58  0.209752       sgd     hard_sigmoid            39                40
# 62  1.180943     Nadam     hard_sigmoid            39                40
# 61  1.181297    Adamax     hard_sigmoid            37                40
# 71  2.301019      adam  ThresholdedReLU             1                 6
# 74  2.301015  Adadelta  ThresholdedReLU             1                 6
# 72  2.301018       sgd  ThresholdedReLU             1                 6
# 70  2.301015      rmsp  ThresholdedReLU             1                 6
# 73  2.301023   Adagrad  ThresholdedReLU             1                 6
# 75  2.301014    Adamax  ThresholdedReLU             1                 6
# 76  2.301006     Nadam  ThresholdedReLU             1                 6
# 45  7.299407   Adagrad         softplus            39                40
# 59  8.381092   Adagrad     hard_sigmoid             1                 6
#
#    min_loss_epoch min_val_loss_epoch
# 20             36                  2
# 15             36                  5
# 69             26                  8
# 64             38                  3
# 29             39                  4
# 55             39                  3
# 13             37                  1
# 8              35                  4
# 49             32                  4
# 7              39                  4
# 19             36                  8
# 34             32                  8
# 27             34                  3
# 63             39                  5
# 12             34                  5
# 33             36                  7
# 50             38                 21
# 28             37                  3
# 68             39                  6
# 11             39                 13
# 40             38                  3
# 22             37                  2
# 54             32                 23
# 26             36                  3
# 14             38                  9
# 32             31                 10
# 48             32                 13
# 21             25                  3
# 43             39                 14
# 39             30                 27
# ..            ...                ...
# 60             38                 27
# 37             38                 38
# 56             39                 37
# 4              31                 27
# 16             36                 37
# 0              39                 27
# 46             39                 29
# 42             32                 29
# 30             35                 36
# 65             39                 39
# 23             37                 30
# 9              39                 37
# 44             39                 38
# 57             38                 36
# 41             38                 39
# 51             39                 39
# 3              39                 39
# 2              38                 39
# 58             39                 39
# 62             36                 35
# 61             39                 39
# 71             39                 10
# 74             38                  4
# 72             34                  7
# 70             31                  9
# 73             31                 30
# 75             30                  4
# 76             33                  9
# 45             39                 39
# 59             38                 23
#
# [77 rows x 12 columns]

# %%
plt.figure(figsize=(20,10))
cmap = get_cmap(experiments * 2)
for d in data:
    plt.plot(range(epochs),
             d['averaged']['val_loss'].tolist(),
             d['col'],
             linestyle=d['line'],
             label=d['disp_name'] + ' Val Loss')
    plt.annotate('%0.4f' % d['averaged']['val_loss'].tolist()[-1], xy=(1, d['averaged']['val_loss'].tolist()[-1]), xytext=(8, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')
plt.xlabel('Epochs')
plt.ylabel('Val Loss')
plt.yscale('log')
plt.legend(loc='upper center',ncol=2)

# %%
plt.figure(figsize=(20,10))
cmap = get_cmap(experiments * 2)
for d in data:
    plt.plot(range(epochs-5,epochs),
             d['averaged']['val_loss'].tolist()[epochs-5:],
             d['col'],
             linestyle=d['line'],
             label=d['disp_name'] + ' Val Loss')
    plt.annotate('%0.4f' % d['averaged']['val_loss'].tolist()[-1], xy=(1, d['averaged']['val_loss'].tolist()[-1]), xytext=(8, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')
plt.xlabel('Epochs')
plt.ylabel('Val Loss')
plt.yscale('log')
plt.legend(loc='center left',ncol=2)

# %%
sorted_by_val_loss = results.sort_values(by=['val_loss'])
sorted_by_val_loss
# Out:
#                       config       acc      loss  val_acc  val_acc_std  \
# 18             relu_Adadelta  0.996517  0.013336  0.99030      0.00050
# 14                 relu_rmsp  0.997008  0.010618  0.99095      0.00005
# 17              relu_Adagrad  0.996217  0.013596  0.98960      0.00020
# 19               relu_Adamax  0.999008  0.003700  0.99010      0.00010
# 16                  relu_sgd  0.988567  0.037533  0.98695      0.00045
# 42             softplus_rmsp  0.988325  0.039041  0.98760      0.00070
# 67        LeakyReLU_Adadelta  0.995608  0.015850  0.98765      0.00065
# 66         LeakyReLU_Adagrad  0.995992  0.015074  0.98740      0.00030
# 52          softsign_Adagrad  0.993192  0.023831  0.98690      0.00040
# 56         hard_sigmoid_rmsp  0.989667  0.034955  0.98675      0.00065
# 53         softsign_Adadelta  0.996767  0.012130  0.98760      0.00070
# 46         softplus_Adadelta  0.988417  0.039039  0.98695      0.00115
# 5             sigmoid_Adamax  0.993342  0.022312  0.98720      0.00030
# 60     hard_sigmoid_Adadelta  0.991533  0.028907  0.98695      0.00075
# 0               sigmoid_rmsp  0.989117  0.037744  0.98595      0.00015
# 65             LeakyReLU_sgd  0.986825  0.043798  0.98575      0.00005
# 4           sigmoid_Adadelta  0.988692  0.037442  0.98615      0.00025
# 47           softplus_Adamax  0.991625  0.025052  0.98800      0.00030
# 1               sigmoid_adam  0.993783  0.020343  0.98745      0.00015
# 68          LeakyReLU_Adamax  0.998317  0.007043  0.98795      0.00015
# 30                   elu_sgd  0.987617  0.041487  0.98560      0.00030
# 10              tanh_Adagrad  0.994567  0.020113  0.98605      0.00015
# 43             softplus_adam  0.996475  0.011536  0.98920      0.00010
# 31               elu_Adagrad  0.994100  0.019882  0.98615      0.00035
# 37                  selu_sgd  0.990000  0.032480  0.98705      0.00065
# 44              softplus_sgd  0.984158  0.050447  0.98540      0.00070
# 32              elu_Adadelta  0.996975  0.010923  0.98770      0.00090
# 11             tanh_Adadelta  0.998217  0.007370  0.98685      0.00005
# 54           softsign_Adamax  0.997683  0.009645  0.98665      0.00075
# 48            softplus_Nadam  0.996192  0.010970  0.98845      0.00035
# ..                       ...       ...       ...      ...          ...
# 28                  elu_rmsp  0.998450  0.005777  0.98665      0.00005
# 26             linear_Adamax  0.997233  0.009907  0.98230      0.00020
# 22               linear_adam  0.997642  0.008563  0.98140      0.00060
# 7                  tanh_rmsp  0.999208  0.003431  0.98535      0.00045
# 21               linear_rmsp  0.996858  0.011363  0.98245      0.00035
# 40               selu_Adamax  0.997500  0.007449  0.98860      0.00090
# 29                  elu_adam  0.999442  0.002010  0.98635      0.00015
# 34                 elu_Nadam  0.998942  0.003902  0.98560      0.00010
# 8                  tanh_adam  0.999033  0.003276  0.98465      0.00095
# 39             selu_Adadelta  0.996717  0.011910  0.98815      0.00095
# 55            softsign_Nadam  0.999458  0.002336  0.98530      0.00000
# 27              linear_Nadam  0.998742  0.004347  0.98055      0.00005
# 13                tanh_Nadam  0.999358  0.002564  0.98340      0.00030
# 35                 selu_rmsp  0.995483  0.026388  0.98830      0.00020
# 3            sigmoid_Adagrad  0.962208  0.128969  0.96795      0.00085
# 36                 selu_adam  0.997150  0.021886  0.98800      0.00020
# 41                selu_Nadam  0.995275  0.060551  0.98785      0.00065
# 2                sigmoid_sgd  0.935250  0.220894  0.94475      0.00125
# 58          hard_sigmoid_sgd  0.934375  0.228841  0.93995      0.01095
# 62        hard_sigmoid_Nadam  0.545992  1.183063  0.54715      0.43365
# 61       hard_sigmoid_Adamax  0.543442  1.190867  0.54780      0.43430
# 76     ThresholdedReLU_Nadam  0.112367  2.301193  0.11350      0.00000
# 75    ThresholdedReLU_Adamax  0.112367  2.301160  0.11350      0.00000
# 74  ThresholdedReLU_Adadelta  0.112367  2.301159  0.11350      0.00000
# 70      ThresholdedReLU_rmsp  0.112367  2.301160  0.11350      0.00000
# 72       ThresholdedReLU_sgd  0.112367  2.301160  0.11350      0.00000
# 71      ThresholdedReLU_adam  0.112367  2.301159  0.11350      0.00000
# 73   ThresholdedReLU_Adagrad  0.112367  2.301160  0.11350      0.00000
# 45          softplus_Adagrad  0.535625  7.316739  0.53820      0.44000
# 59      hard_sigmoid_Adagrad  0.108392  8.368131  0.10815      0.00535
#
#     val_loss       opt              act max_acc_epoch max_val_acc_epoch  \
# 18  0.031611  Adadelta             relu            36                40
# 14  0.034012      rmsp             relu            27                33
# 17  0.034349   Adagrad             relu            36                30
# 19  0.038453    Adamax             relu            36                35
# 16  0.040202       sgd             relu            36                40
# 42  0.040711      rmsp         softplus            36                40
# 67  0.041028  Adadelta        LeakyReLU            31                31
# 66  0.041348   Adagrad        LeakyReLU            35                32
# 52  0.041972   Adagrad         softsign            29                26
# 56  0.042015      rmsp     hard_sigmoid            33                40
# 53  0.042128  Adadelta         softsign            33                33
# 46  0.042587  Adadelta         softplus            39                39
# 5   0.042756    Adamax          sigmoid            38                40
# 60  0.043124  Adadelta     hard_sigmoid            37                40
# 0   0.043256      rmsp          sigmoid            39                40
# 65  0.043294       sgd        LeakyReLU            38                40
# 4   0.043468  Adadelta          sigmoid            34                39
# 47  0.043478    Adamax         softplus            38                40
# 1   0.044014      adam          sigmoid            32                40
# 68  0.044167    Adamax        LeakyReLU            39                33
# 30  0.044514       sgd              elu            35                39
# 10  0.044873   Adagrad             tanh            32                35
# 43  0.045908      adam         softplus            39                40
# 31  0.045920   Adagrad              elu            34                39
# 37  0.045984       sgd             selu            38                40
# 44  0.046033       sgd         softplus            37                40
# 32  0.046143  Adadelta              elu            34                33
# 11  0.047057  Adadelta             tanh            34                33
# 54  0.047170    Adamax         softsign            36                40
# 48  0.047207     Nadam         softplus            36                40
# ..       ...       ...              ...           ...               ...
# 28  0.065727      rmsp              elu            32                37
# 26  0.069029    Adamax           linear            38                38
# 22  0.072007      adam           linear            29                32
# 7   0.072951      rmsp             tanh            39                33
# 21  0.073513      rmsp           linear            31                36
# 40  0.074837    Adamax             selu            38                40
# 29  0.075654      adam              elu            38                39
# 34  0.076594     Nadam              elu            33                36
# 8   0.078167      adam             tanh            29                38
# 39  0.083277  Adadelta             selu            37                40
# 55  0.089562     Nadam         softsign            30                40
# 27  0.094403     Nadam           linear            33                32
# 13  0.101519     Nadam             tanh            30                40
# 35  0.106640      rmsp             selu            29                37
# 3   0.109082   Adagrad          sigmoid            38                40
# 36  0.136906      adam             selu            39                40
# 41  0.167950     Nadam             selu            38                40
# 2   0.195983       sgd          sigmoid            38                40
# 58  0.209752       sgd     hard_sigmoid            39                40
# 62  1.180943     Nadam     hard_sigmoid            39                40
# 61  1.181297    Adamax     hard_sigmoid            37                40
# 76  2.301006     Nadam  ThresholdedReLU             1                 6
# 75  2.301014    Adamax  ThresholdedReLU             1                 6
# 74  2.301015  Adadelta  ThresholdedReLU             1                 6
# 70  2.301015      rmsp  ThresholdedReLU             1                 6
# 72  2.301018       sgd  ThresholdedReLU             1                 6
# 71  2.301019      adam  ThresholdedReLU             1                 6
# 73  2.301023   Adagrad  ThresholdedReLU             1                 6
# 45  7.299407   Adagrad         softplus            39                40
# 59  8.381092   Adagrad     hard_sigmoid             1                 6
#
#    min_loss_epoch min_val_loss_epoch
# 18             37                 19
# 14             38                  9
# 17             36                  9
# 19             36                  8
# 16             36                 37
# 42             32                 29
# 67             33                 12
# 66             31                 18
# 52             32                 27
# 56             39                 37
# 53             31                 24
# 46             39                 29
# 5              38                 39
# 60             38                 27
# 0              39                 27
# 65             39                 39
# 4              31                 27
# 47             38                 37
# 1              36                 28
# 68             39                  6
# 30             35                 36
# 10             32                 22
# 43             39                 14
# 31             33                 18
# 37             38                 38
# 44             39                 38
# 32             31                 10
# 11             39                 13
# 54             32                 23
# 48             32                 13
# ..            ...                ...
# 28             37                  3
# 26             36                  3
# 22             37                  2
# 7              39                  4
# 21             25                  3
# 40             38                  3
# 29             39                  4
# 34             32                  8
# 8              35                  4
# 39             30                 27
# 55             39                  3
# 27             34                  3
# 13             37                  1
# 35             29                 32
# 3              39                 39
# 36             39                  1
# 41             38                 39
# 2              38                 39
# 58             39                 39
# 62             36                 35
# 61             39                 39
# 76             33                  9
# 75             30                  4
# 74             38                  4
# 70             31                  9
# 72             34                  7
# 71             39                 10
# 73             31                 30
# 45             39                 39
# 59             38                 23
#
# [77 rows x 12 columns]

# %%
plt.figure(figsize=(20,10))
cmap = get_cmap(experiments * 2)

for d in data:
    plt.plot(range(epochs),
             d['averaged']['acc'].tolist(),
             d['col'],
             linestyle=d['line'],
             label=d['disp_name'] + ' Acc')
    plt.annotate('%0.4f' % d['averaged']['acc'].tolist()[-1], xy=(1, d['averaged']['acc'].tolist()[-1]), xytext=(8, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.yscale('log')
plt.legend(loc='lower center',ncol=2)

# %%
plt.figure(figsize=(20,10))
cmap = get_cmap(experiments * 2)

for d in data:
    plt.plot(range(epochs-5,epochs),
             d['averaged']['acc'].tolist()[epochs-5:],
             d['col'],
             linestyle=d['line'],
             label=d['disp_name'] + ' Acc')
    plt.annotate('%0.4f' % d['averaged']['acc'].tolist()[-1], xy=(1, d['averaged']['acc'].tolist()[-1]), xytext=(8, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.yscale('log')
plt.legend(loc='center left',ncol=2)

# %%
sorted_by_acc = results.sort_values(by=['acc'], ascending=False)
sorted_by_acc
# Out:
#                       config       acc      loss  val_acc  val_acc_std  \
# 20                relu_Nadam  0.999942  0.000556  0.99090      0.00030
# 15                 relu_adam  0.999875  0.000714  0.99055      0.00075
# 69           LeakyReLU_Nadam  0.999842  0.001276  0.98830      0.00060
# 64            LeakyReLU_adam  0.999633  0.001892  0.98880      0.00030
# 55            softsign_Nadam  0.999458  0.002336  0.98530      0.00000
# 29                  elu_adam  0.999442  0.002010  0.98635      0.00015
# 13                tanh_Nadam  0.999358  0.002564  0.98340      0.00030
# 7                  tanh_rmsp  0.999208  0.003431  0.98535      0.00045
# 49             softsign_rmsp  0.999183  0.003424  0.98625      0.00015
# 12               tanh_Adamax  0.999042  0.004561  0.98715      0.00005
# 8                  tanh_adam  0.999033  0.003276  0.98465      0.00095
# 19               relu_Adamax  0.999008  0.003700  0.99010      0.00010
# 34                 elu_Nadam  0.998942  0.003902  0.98560      0.00010
# 63            LeakyReLU_rmsp  0.998792  0.004526  0.98800      0.00030
# 27              linear_Nadam  0.998742  0.004347  0.98055      0.00005
# 50             softsign_adam  0.998725  0.005240  0.98620      0.00070
# 33                elu_Adamax  0.998617  0.005189  0.98730      0.00020
# 28                  elu_rmsp  0.998450  0.005777  0.98665      0.00005
# 68          LeakyReLU_Adamax  0.998317  0.007043  0.98795      0.00015
# 11             tanh_Adadelta  0.998217  0.007370  0.98685      0.00005
# 54           softsign_Adamax  0.997683  0.009645  0.98665      0.00075
# 22               linear_adam  0.997642  0.008563  0.98140      0.00060
# 40               selu_Adamax  0.997500  0.007449  0.98860      0.00090
# 26             linear_Adamax  0.997233  0.009907  0.98230      0.00020
# 36                 selu_adam  0.997150  0.021886  0.98800      0.00020
# 14                 relu_rmsp  0.997008  0.010618  0.99095      0.00005
# 32              elu_Adadelta  0.996975  0.010923  0.98770      0.00090
# 21               linear_rmsp  0.996858  0.011363  0.98245      0.00035
# 53         softsign_Adadelta  0.996767  0.012130  0.98760      0.00070
# 39             selu_Adadelta  0.996717  0.011910  0.98815      0.00095
# ..                       ...       ...       ...      ...          ...
# 60     hard_sigmoid_Adadelta  0.991533  0.028907  0.98695      0.00075
# 38              selu_Adagrad  0.991417  0.027029  0.98800      0.00030
# 37                  selu_sgd  0.990000  0.032480  0.98705      0.00065
# 56         hard_sigmoid_rmsp  0.989667  0.034955  0.98675      0.00065
# 0               sigmoid_rmsp  0.989117  0.037744  0.98595      0.00015
# 4           sigmoid_Adadelta  0.988692  0.037442  0.98615      0.00025
# 16                  relu_sgd  0.988567  0.037533  0.98695      0.00045
# 46         softplus_Adadelta  0.988417  0.039039  0.98695      0.00115
# 42             softplus_rmsp  0.988325  0.039041  0.98760      0.00070
# 30                   elu_sgd  0.987617  0.041487  0.98560      0.00030
# 65             LeakyReLU_sgd  0.986825  0.043798  0.98575      0.00005
# 9                   tanh_sgd  0.986633  0.046166  0.98410      0.00050
# 23                linear_sgd  0.986400  0.045110  0.98290      0.00070
# 44              softplus_sgd  0.984158  0.050447  0.98540      0.00070
# 51              softsign_sgd  0.982583  0.060611  0.98175      0.00035
# 57         hard_sigmoid_adam  0.982492  0.054867  0.98355      0.00095
# 3            sigmoid_Adagrad  0.962208  0.128969  0.96795      0.00085
# 2                sigmoid_sgd  0.935250  0.220894  0.94475      0.00125
# 58          hard_sigmoid_sgd  0.934375  0.228841  0.93995      0.01095
# 62        hard_sigmoid_Nadam  0.545992  1.183063  0.54715      0.43365
# 61       hard_sigmoid_Adamax  0.543442  1.190867  0.54780      0.43430
# 45          softplus_Adagrad  0.535625  7.316739  0.53820      0.44000
# 70      ThresholdedReLU_rmsp  0.112367  2.301160  0.11350      0.00000
# 71      ThresholdedReLU_adam  0.112367  2.301159  0.11350      0.00000
# 72       ThresholdedReLU_sgd  0.112367  2.301160  0.11350      0.00000
# 73   ThresholdedReLU_Adagrad  0.112367  2.301160  0.11350      0.00000
# 74  ThresholdedReLU_Adadelta  0.112367  2.301159  0.11350      0.00000
# 75    ThresholdedReLU_Adamax  0.112367  2.301160  0.11350      0.00000
# 76     ThresholdedReLU_Nadam  0.112367  2.301193  0.11350      0.00000
# 59      hard_sigmoid_Adagrad  0.108392  8.368131  0.10815      0.00535
#
#     val_loss       opt              act max_acc_epoch max_val_acc_epoch  \
# 20  0.050930     Nadam             relu            26                33
# 15  0.047360      adam             relu            33                29
# 69  0.054539     Nadam        LeakyReLU            31                39
# 64  0.051364      adam        LeakyReLU            29                39
# 55  0.089562     Nadam         softsign            30                40
# 29  0.075654      adam              elu            38                39
# 13  0.101519     Nadam             tanh            30                40
# 7   0.072951      rmsp             tanh            39                33
# 49  0.065608      rmsp         softsign            39                36
# 12  0.051733    Adamax             tanh            34                35
# 8   0.078167      adam             tanh            29                38
# 19  0.038453    Adamax             relu            36                35
# 34  0.076594     Nadam              elu            33                36
# 63  0.052813      rmsp        LeakyReLU            29                35
# 27  0.094403     Nadam           linear            33                32
# 50  0.058172      adam         softsign            38                36
# 33  0.055672    Adamax              elu            36                31
# 28  0.065727      rmsp              elu            32                37
# 68  0.044167    Adamax        LeakyReLU            39                33
# 11  0.047057  Adadelta             tanh            34                33
# 54  0.047170    Adamax         softsign            36                40
# 22  0.072007      adam           linear            29                32
# 40  0.074837    Adamax             selu            38                40
# 26  0.069029    Adamax           linear            38                38
# 36  0.136906      adam             selu            39                40
# 14  0.034012      rmsp             relu            27                33
# 32  0.046143  Adadelta              elu            34                33
# 21  0.073513      rmsp           linear            31                36
# 53  0.042128  Adadelta         softsign            33                33
# 39  0.083277  Adadelta             selu            37                40
# ..       ...       ...              ...           ...               ...
# 60  0.043124  Adadelta     hard_sigmoid            37                40
# 38  0.048406   Adagrad             selu            34                34
# 37  0.045984       sgd             selu            38                40
# 56  0.042015      rmsp     hard_sigmoid            33                40
# 0   0.043256      rmsp          sigmoid            39                40
# 4   0.043468  Adadelta          sigmoid            34                39
# 16  0.040202       sgd             relu            36                40
# 46  0.042587  Adadelta         softplus            39                39
# 42  0.040711      rmsp         softplus            36                40
# 30  0.044514       sgd              elu            35                39
# 65  0.043294       sgd        LeakyReLU            38                40
# 9   0.049474       sgd             tanh            37                40
# 23  0.051380       sgd           linear            37                40
# 44  0.046033       sgd         softplus            37                40
# 51  0.060373       sgd         softsign            39                40
# 57  0.051467      adam     hard_sigmoid            34                40
# 3   0.109082   Adagrad          sigmoid            38                40
# 2   0.195983       sgd          sigmoid            38                40
# 58  0.209752       sgd     hard_sigmoid            39                40
# 62  1.180943     Nadam     hard_sigmoid            39                40
# 61  1.181297    Adamax     hard_sigmoid            37                40
# 45  7.299407   Adagrad         softplus            39                40
# 70  2.301015      rmsp  ThresholdedReLU             1                 6
# 71  2.301019      adam  ThresholdedReLU             1                 6
# 72  2.301018       sgd  ThresholdedReLU             1                 6
# 73  2.301023   Adagrad  ThresholdedReLU             1                 6
# 74  2.301015  Adadelta  ThresholdedReLU             1                 6
# 75  2.301014    Adamax  ThresholdedReLU             1                 6
# 76  2.301006     Nadam  ThresholdedReLU             1                 6
# 59  8.381092   Adagrad     hard_sigmoid             1                 6
#
#    min_loss_epoch min_val_loss_epoch
# 20             36                  2
# 15             36                  5
# 69             26                  8
# 64             38                  3
# 55             39                  3
# 29             39                  4
# 13             37                  1
# 7              39                  4
# 49             32                  4
# 12             34                  5
# 8              35                  4
# 19             36                  8
# 34             32                  8
# 63             39                  5
# 27             34                  3
# 50             38                 21
# 33             36                  7
# 28             37                  3
# 68             39                  6
# 11             39                 13
# 54             32                 23
# 22             37                  2
# 40             38                  3
# 26             36                  3
# 36             39                  1
# 14             38                  9
# 32             31                 10
# 21             25                  3
# 53             31                 24
# 39             30                 27
# ..            ...                ...
# 60             38                 27
# 38             33                 27
# 37             38                 38
# 56             39                 37
# 0              39                 27
# 4              31                 27
# 16             36                 37
# 46             39                 29
# 42             32                 29
# 30             35                 36
# 65             39                 39
# 9              39                 37
# 23             37                 30
# 44             39                 38
# 51             39                 39
# 57             38                 36
# 3              39                 39
# 2              38                 39
# 58             39                 39
# 62             36                 35
# 61             39                 39
# 45             39                 39
# 70             31                  9
# 71             39                 10
# 72             34                  7
# 73             31                 30
# 74             38                  4
# 75             30                  4
# 76             33                  9
# 59             38                 23
#
# [77 rows x 12 columns]

# %%
plt.figure(figsize=(20,10))
cmap = get_cmap(experiments * 2)

for d in data:
    plt.plot(range(epochs),
             d['averaged']['val_acc'].tolist(),
             d['col'],
             linestyle=d['line'],
             label=d['disp_name'] + ' Val Acc')
    plt.annotate('%0.4f' % d['averaged']['val_acc'].tolist()[-1], xy=(1, d['averaged']['val_acc'].tolist()[-1]), xytext=(8, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')
plt.xlabel('Epochs')
plt.ylabel('Val Accuracy')
plt.yscale('log')
plt.legend(loc='lower center',ncol=2)

# %%
plt.figure(figsize=(20,10))
cmap = get_cmap(experiments * 2)

for d in data:
    plt.plot(range(epochs-5,epochs),
             d['averaged']['val_acc'].tolist()[epochs-5:],
             d['col'],
             linestyle=d['line'],
             label=d['disp_name'] + ' Val Acc')
    plt.annotate('%0.4f' % d['averaged']['val_acc'].tolist()[-1], xy=(1, d['averaged']['val_acc'].tolist()[-1]), xytext=(8, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')
plt.xlabel('Epochs')
plt.ylabel('Val Accuracy')
plt.yscale('log')
plt.legend(loc='center left',ncol=2)

# %%
sorted_by_val_acc = results.sort_values(by=['val_acc'], ascending=False)
sorted_by_val_acc
# Out:
#                       config       acc      loss  val_acc  val_acc_std  \
# 14                 relu_rmsp  0.997008  0.010618  0.99095      0.00005
# 20                relu_Nadam  0.999942  0.000556  0.99090      0.00030
# 15                 relu_adam  0.999875  0.000714  0.99055      0.00075
# 18             relu_Adadelta  0.996517  0.013336  0.99030      0.00050
# 19               relu_Adamax  0.999008  0.003700  0.99010      0.00010
# 17              relu_Adagrad  0.996217  0.013596  0.98960      0.00020
# 43             softplus_adam  0.996475  0.011536  0.98920      0.00010
# 64            LeakyReLU_adam  0.999633  0.001892  0.98880      0.00030
# 40               selu_Adamax  0.997500  0.007449  0.98860      0.00090
# 48            softplus_Nadam  0.996192  0.010970  0.98845      0.00035
# 69           LeakyReLU_Nadam  0.999842  0.001276  0.98830      0.00060
# 35                 selu_rmsp  0.995483  0.026388  0.98830      0.00020
# 39             selu_Adadelta  0.996717  0.011910  0.98815      0.00095
# 36                 selu_adam  0.997150  0.021886  0.98800      0.00020
# 47           softplus_Adamax  0.991625  0.025052  0.98800      0.00030
# 38              selu_Adagrad  0.991417  0.027029  0.98800      0.00030
# 63            LeakyReLU_rmsp  0.998792  0.004526  0.98800      0.00030
# 68          LeakyReLU_Adamax  0.998317  0.007043  0.98795      0.00015
# 41                selu_Nadam  0.995275  0.060551  0.98785      0.00065
# 32              elu_Adadelta  0.996975  0.010923  0.98770      0.00090
# 67        LeakyReLU_Adadelta  0.995608  0.015850  0.98765      0.00065
# 42             softplus_rmsp  0.988325  0.039041  0.98760      0.00070
# 53         softsign_Adadelta  0.996767  0.012130  0.98760      0.00070
# 1               sigmoid_adam  0.993783  0.020343  0.98745      0.00015
# 66         LeakyReLU_Adagrad  0.995992  0.015074  0.98740      0.00030
# 33                elu_Adamax  0.998617  0.005189  0.98730      0.00020
# 5             sigmoid_Adamax  0.993342  0.022312  0.98720      0.00030
# 12               tanh_Adamax  0.999042  0.004561  0.98715      0.00005
# 37                  selu_sgd  0.990000  0.032480  0.98705      0.00065
# 6              sigmoid_Nadam  0.996150  0.013087  0.98700      0.00070
# ..                       ...       ...       ...      ...          ...
# 30                   elu_sgd  0.987617  0.041487  0.98560      0.00030
# 44              softplus_sgd  0.984158  0.050447  0.98540      0.00070
# 7                  tanh_rmsp  0.999208  0.003431  0.98535      0.00045
# 55            softsign_Nadam  0.999458  0.002336  0.98530      0.00000
# 8                  tanh_adam  0.999033  0.003276  0.98465      0.00095
# 25           linear_Adadelta  0.994550  0.019373  0.98410      0.00020
# 9                   tanh_sgd  0.986633  0.046166  0.98410      0.00050
# 24            linear_Adagrad  0.992517  0.026243  0.98405      0.00045
# 57         hard_sigmoid_adam  0.982492  0.054867  0.98355      0.00095
# 13                tanh_Nadam  0.999358  0.002564  0.98340      0.00030
# 23                linear_sgd  0.986400  0.045110  0.98290      0.00070
# 21               linear_rmsp  0.996858  0.011363  0.98245      0.00035
# 26             linear_Adamax  0.997233  0.009907  0.98230      0.00020
# 51              softsign_sgd  0.982583  0.060611  0.98175      0.00035
# 22               linear_adam  0.997642  0.008563  0.98140      0.00060
# 27              linear_Nadam  0.998742  0.004347  0.98055      0.00005
# 3            sigmoid_Adagrad  0.962208  0.128969  0.96795      0.00085
# 2                sigmoid_sgd  0.935250  0.220894  0.94475      0.00125
# 58          hard_sigmoid_sgd  0.934375  0.228841  0.93995      0.01095
# 61       hard_sigmoid_Adamax  0.543442  1.190867  0.54780      0.43430
# 62        hard_sigmoid_Nadam  0.545992  1.183063  0.54715      0.43365
# 45          softplus_Adagrad  0.535625  7.316739  0.53820      0.44000
# 70      ThresholdedReLU_rmsp  0.112367  2.301160  0.11350      0.00000
# 71      ThresholdedReLU_adam  0.112367  2.301159  0.11350      0.00000
# 72       ThresholdedReLU_sgd  0.112367  2.301160  0.11350      0.00000
# 73   ThresholdedReLU_Adagrad  0.112367  2.301160  0.11350      0.00000
# 74  ThresholdedReLU_Adadelta  0.112367  2.301159  0.11350      0.00000
# 75    ThresholdedReLU_Adamax  0.112367  2.301160  0.11350      0.00000
# 76     ThresholdedReLU_Nadam  0.112367  2.301193  0.11350      0.00000
# 59      hard_sigmoid_Adagrad  0.108392  8.368131  0.10815      0.00535
#
#     val_loss       opt              act max_acc_epoch max_val_acc_epoch  \
# 14  0.034012      rmsp             relu            27                33
# 20  0.050930     Nadam             relu            26                33
# 15  0.047360      adam             relu            33                29
# 18  0.031611  Adadelta             relu            36                40
# 19  0.038453    Adamax             relu            36                35
# 17  0.034349   Adagrad             relu            36                30
# 43  0.045908      adam         softplus            39                40
# 64  0.051364      adam        LeakyReLU            29                39
# 40  0.074837    Adamax             selu            38                40
# 48  0.047207     Nadam         softplus            36                40
# 69  0.054539     Nadam        LeakyReLU            31                39
# 35  0.106640      rmsp             selu            29                37
# 39  0.083277  Adadelta             selu            37                40
# 36  0.136906      adam             selu            39                40
# 47  0.043478    Adamax         softplus            38                40
# 38  0.048406   Adagrad             selu            34                34
# 63  0.052813      rmsp        LeakyReLU            29                35
# 68  0.044167    Adamax        LeakyReLU            39                33
# 41  0.167950     Nadam             selu            38                40
# 32  0.046143  Adadelta              elu            34                33
# 67  0.041028  Adadelta        LeakyReLU            31                31
# 42  0.040711      rmsp         softplus            36                40
# 53  0.042128  Adadelta         softsign            33                33
# 1   0.044014      adam          sigmoid            32                40
# 66  0.041348   Adagrad        LeakyReLU            35                32
# 33  0.055672    Adamax              elu            36                31
# 5   0.042756    Adamax          sigmoid            38                40
# 12  0.051733    Adamax             tanh            34                35
# 37  0.045984       sgd             selu            38                40
# 6   0.047434     Nadam          sigmoid            39                40
# ..       ...       ...              ...           ...               ...
# 30  0.044514       sgd              elu            35                39
# 44  0.046033       sgd         softplus            37                40
# 7   0.072951      rmsp             tanh            39                33
# 55  0.089562     Nadam         softsign            30                40
# 8   0.078167      adam             tanh            29                38
# 25  0.057806  Adadelta           linear            30                39
# 9   0.049474       sgd             tanh            37                40
# 24  0.052022   Adagrad           linear            33                33
# 57  0.051467      adam     hard_sigmoid            34                40
# 13  0.101519     Nadam             tanh            30                40
# 23  0.051380       sgd           linear            37                40
# 21  0.073513      rmsp           linear            31                36
# 26  0.069029    Adamax           linear            38                38
# 51  0.060373       sgd         softsign            39                40
# 22  0.072007      adam           linear            29                32
# 27  0.094403     Nadam           linear            33                32
# 3   0.109082   Adagrad          sigmoid            38                40
# 2   0.195983       sgd          sigmoid            38                40
# 58  0.209752       sgd     hard_sigmoid            39                40
# 61  1.181297    Adamax     hard_sigmoid            37                40
# 62  1.180943     Nadam     hard_sigmoid            39                40
# 45  7.299407   Adagrad         softplus            39                40
# 70  2.301015      rmsp  ThresholdedReLU             1                 6
# 71  2.301019      adam  ThresholdedReLU             1                 6
# 72  2.301018       sgd  ThresholdedReLU             1                 6
# 73  2.301023   Adagrad  ThresholdedReLU             1                 6
# 74  2.301015  Adadelta  ThresholdedReLU             1                 6
# 75  2.301014    Adamax  ThresholdedReLU             1                 6
# 76  2.301006     Nadam  ThresholdedReLU             1                 6
# 59  8.381092   Adagrad     hard_sigmoid             1                 6
#
#    min_loss_epoch min_val_loss_epoch
# 14             38                  9
# 20             36                  2
# 15             36                  5
# 18             37                 19
# 19             36                  8
# 17             36                  9
# 43             39                 14
# 64             38                  3
# 40             38                  3
# 48             32                 13
# 69             26                  8
# 35             29                 32
# 39             30                 27
# 36             39                  1
# 47             38                 37
# 38             33                 27
# 63             39                  5
# 68             39                  6
# 41             38                 39
# 32             31                 10
# 67             33                 12
# 42             32                 29
# 53             31                 24
# 1              36                 28
# 66             31                 18
# 33             36                  7
# 5              38                 39
# 12             34                  5
# 37             38                 38
# 6              36                 19
# ..            ...                ...
# 30             35                 36
# 44             39                 38
# 7              39                  4
# 55             39                  3
# 8              35                  4
# 25             31                 11
# 9              39                 37
# 24             28                 12
# 57             38                 36
# 13             37                  1
# 23             37                 30
# 21             25                  3
# 26             36                  3
# 51             39                 39
# 22             37                  2
# 27             34                  3
# 3              39                 39
# 2              38                 39
# 58             39                 39
# 61             39                 39
# 62             36                 35
# 45             39                 39
# 70             31                  9
# 71             39                 10
# 72             34                  7
# 73             31                 30
# 74             38                  4
# 75             30                  4
# 76             33                  9
# 59             38                 23
#
# [77 rows x 12 columns]

# %%
print('---Top by Accuracy---')
print(sorted_by_acc.head())
print('\n---Top by Val Accuracy---')
print(sorted_by_val_acc.head())
print('\n---Top by Loss---')
print(sorted_by_loss.head())
print('\n---Top by Val Loss---')
print(sorted_by_val_loss.head())
# Out:
# ---Top by Accuracy---
#             config       acc      loss  val_acc  val_loss       opt  \
# 29     selu_Adamax  0.999200  0.002658   0.9910  0.067185    Adamax
# 25       selu_adam  0.999083  0.002970   0.9916  0.075527      adam
# 19       relu_adam  0.998483  0.004294   0.9940  0.027388      adam
# 28   selu_Adadelta  0.997967  0.006892   0.9912  0.060575  Adadelta
# 7   LeakyReLU_adam  0.997783  0.007051   0.9907  0.035072      adam
#
#           act  max_acc_epoch  max_val_acc_epoch  min_loss_epoch  \
# 29       selu           29.0               27.0            28.0
# 25       selu           30.0               20.0            30.0
# 19       relu           25.0               24.0            29.0
# 28       selu           25.0               18.0            25.0
# 7   LeakyReLU           25.0               24.0            25.0
#
#     min_val_loss_epoch
# 29                 5.0
# 25                17.0
# 19                11.0
# 28                 4.0
# 7                 13.0
#
# ---Top by Val Accuracy---
#           config       acc      loss  val_acc  val_loss      opt   act  \
# 19     relu_adam  0.998483  0.004294   0.9940  0.027388     adam  relu
# 23   relu_Adamax  0.997167  0.009108   0.9928  0.029723   Adamax  relu
# 18     relu_rmsp  0.988333  0.040403   0.9916  0.029125     rmsp  relu
# 21  relu_Adagrad  0.992083  0.024678   0.9916  0.024921  Adagrad  relu
# 25     selu_adam  0.999083  0.002970   0.9916  0.075527     adam  selu
#
#     max_acc_epoch  max_val_acc_epoch  min_loss_epoch  min_val_loss_epoch
# 19           25.0               24.0            29.0                11.0
# 23           27.0               22.0            27.0                12.0
# 18           26.0               18.0            25.0                24.0
# 21           19.0               12.0            25.0                20.0
# 25           30.0               20.0            30.0                17.0
#
# ---Top by Loss---
#             config       acc      loss  val_acc  val_loss       opt  \
# 29     selu_Adamax  0.999200  0.002658   0.9910  0.067185    Adamax
# 25       selu_adam  0.999083  0.002970   0.9916  0.075527      adam
# 19       relu_adam  0.998483  0.004294   0.9940  0.027388      adam
# 28   selu_Adadelta  0.997967  0.006892   0.9912  0.060575  Adadelta
# 7   LeakyReLU_adam  0.997783  0.007051   0.9907  0.035072      adam
#
#           act  max_acc_epoch  max_val_acc_epoch  min_loss_epoch  \
# 29       selu           29.0               27.0            28.0
# 25       selu           30.0               20.0            30.0
# 19       relu           25.0               24.0            29.0
# 28       selu           25.0               18.0            25.0
# 7   LeakyReLU           25.0               24.0            25.0
#
#     min_val_loss_epoch
# 29                 5.0
# 25                17.0
# 19                11.0
# 28                 4.0
# 7                 13.0
#
# ---Top by Val Loss---
#            config       acc      loss  val_acc  val_loss       opt   act  \
# 21   relu_Adagrad  0.992083  0.024678   0.9916  0.024921   Adagrad  relu
# 19      relu_adam  0.998483  0.004294   0.9940  0.027388      adam  relu
# 22  relu_Adadelta  0.990900  0.032361   0.9912  0.027849  Adadelta  relu
# 18      relu_rmsp  0.988333  0.040403   0.9916  0.029125      rmsp  relu
# 23    relu_Adamax  0.997167  0.009108   0.9928  0.029723    Adamax  relu
#
#     max_acc_epoch  max_val_acc_epoch  min_loss_epoch  min_val_loss_epoch
# 21           19.0               12.0            25.0                20.0
# 19           25.0               24.0            29.0                11.0
# 22           28.0               23.0            30.0                25.0
# 18           26.0               18.0            25.0                24.0
# 23           27.0               22.0            27.0                12.0

# %%
results['acc_score'] = (results['acc'] - results['acc'].min()) / (results['acc'].max() - results['acc'].min())
results['val_acc_score'] = (results['val_acc'] - results['val_acc'].min()) / (results['val_acc'].max() - results['val_acc'].min())
results['loss_score'] = 1 - (results['loss'] - results['loss'].min()) / (results['loss'].max() - results['loss'].min())
results['val_loss_score'] = 1 - (results['val_loss'] - results['val_loss'].min()) / (results['val_loss'].max() - results['val_loss'].min())
results['val_acc_epoch_score'] = 1 - (results['max_val_acc_epoch'] - results['max_val_acc_epoch'].min()) / (results['max_val_acc_epoch'].max() - results['max_val_acc_epoch'].min())
results['total_score'] = results['acc_score'] * 0.5 + results['loss_score'] * 0.1 + results['val_acc_score'] + results['val_loss_score'] * 0.2 + results['val_acc_epoch_score'] * 0.5
results['total_score_norm'] = (results['total_score'] - results['total_score'].min()) / (results['total_score'].max() - results['total_score'].min())

# %%
sorted_by_score = results.sort_values(by=['total_score_norm'], ascending=False)
sorted_by_score.reset_index()
# Out:
#    index            config       acc      loss  val_acc  val_loss       opt  \
# 0      1      sigmoid_adam  0.997183  0.008879   0.9915  0.035084      adam
# 1      0      sigmoid_rmsp  0.978967  0.073984   0.9850  0.049791      rmsp
# 2      4  sigmoid_Adadelta  0.985267  0.050691   0.9876  0.039324  Adadelta
# 3      5    sigmoid_Adamax  0.927100  0.254242   0.9669  0.114263    Adamax
# 4      6     sigmoid_Nadam  0.895550  0.390461   0.9267  0.271237     Nadam
# 5      2       sigmoid_sgd  0.110917  2.301803   0.1135  2.300946       sgd
# 6      3   sigmoid_Adagrad  0.107017  2.302709   0.1135  2.301031   Adagrad
#
#        act  max_acc_epoch  max_val_acc_epoch  min_loss_epoch  \
# 0  sigmoid           46.0               38.0            47.0
# 1  sigmoid           42.0               39.0            45.0
# 2  sigmoid           50.0               50.0            50.0
# 3  sigmoid           50.0               49.0            50.0
# 4  sigmoid           50.0               49.0            50.0
# 5  sigmoid            3.0                1.0             3.0
# 6  sigmoid           25.0                1.0            50.0
#
#    min_val_loss_epoch  acc_score  val_acc_score  loss_score  val_loss_score  \
# 0                39.0   1.000000       1.000000    1.000000        1.000000
# 1                50.0   0.979536       0.992597    0.971617        0.993510
# 2                50.0   0.986613       0.995558    0.981772        0.998129
# 3                49.0   0.921269       0.971982    0.893034        0.965057
# 4                50.0   0.885827       0.926196    0.833649        0.895782
# 5                 3.0   0.004381       0.000000    0.000395        0.000037
# 6                 9.0   0.000000       0.000000    0.000000        0.000000
#
#    val_acc_epoch_score  total_score  total_score_norm
# 0             0.244898     1.922449          1.000000
# 1             0.224490     1.890473          0.977521
# 2             0.000000     1.786668          0.904544
# 3             0.020408     1.725135          0.861286
# 4             0.020408     1.641835          0.802724
# 5             1.000000     0.502238          0.001573
# 6             1.000000     0.500000          0.000000

# %%
sorted_by_score.to_csv('./results.csv')

# %%
val_loss_tbl = pd.DataFrame(index=['Adadelta', 'Adagrad', 'adam', 'Adamax', 'Nadam', 'rmsp', 'sgd'], 
                            columns=['elu', 'hard_sigmoid', 'LeakyReLU', 'linear', 'PReLU', 'relu', 'selu', 'sigmoid', 'softplus', 
                                     'softsign', 'tanh', 'ThresholdedReLU'])
